# %% [markdown]
# # Texas Licenses
#
# We originall got our dataset from the [License Files page](https://www.license.state.tx.us/licensesearch/licfile.asp) from the Texas Department of Licensing and Regulation, but they've changed around since then! I'm pretty sure it's [this dataset](https://www.opendatanetwork.com/dataset/data.texas.gov/7358-krk7), but we'll just use a local version instead of the most current.

# %% [markdown]
# # PART ONE: OPENING UP OUR DATASET

# %% [markdown]
# ## 0. Do your setup
#
# Import what you need to import, etc.

# %%
import pandas as pd
# %matplotlib inline

import re

import numpy as np

# %matplotlib inline

df= pd.read_csv("licfile.csv")
# Out:
# C:\Users\Shaleen\AppData\Local\Programs\Python\Python37-32\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (1,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## 1. Open the file
#
# We'll start with `licfile.csv`, which is a list of licenses.

# %%
df
# Out:
#                      Associate Auctioneer   7326       ANGELINA  \
# 0                    Associate Auctioneer   7962         UPSHUR
# 1                    Associate Auctioneer   8406         WILSON
# 2                    Associate Auctioneer  10543         HARRIS
# 3                    Associate Auctioneer  10642           BELL
# 4                    Associate Auctioneer  15650   OUT OF STATE
# 5                    Associate Auctioneer  15698   OUT OF STATE
# 6                    Associate Auctioneer  15810          MILAM
# 7                    Associate Auctioneer  15835   OUT OF STATE
# 8                    Associate Auctioneer  16784   OUT OF STATE
# 9                    Associate Auctioneer  16893          LAMAR
# 10                   Associate Auctioneer  16969    NACOGDOCHES
# 11                   Associate Auctioneer  16990          BEXAR
# 12                   Associate Auctioneer  17072          ECTOR
# 13                   Associate Auctioneer  17108        KAUFMAN
# 14                   Associate Auctioneer  17241           HOOD
# 15                   Associate Auctioneer  17242          ERATH
# 16                   Associate Auctioneer  17669        JOHNSON
# 17                   Associate Auctioneer  17671          MILLS
# 18                   Associate Auctioneer  17672          BROWN
# 19                   Associate Auctioneer  17675         UPSHUR
# 20                   Associate Auctioneer  17676        JOHNSON
# 21                   Associate Auctioneer  17679          ELLIS
# 22                   Associate Auctioneer  17680           BELL
# 23                   Associate Auctioneer  17685       SAN SABA
# 24                   Associate Auctioneer  17687         HARRIS
# 25                   Associate Auctioneer  17689         DALLAM
# 26                   Associate Auctioneer  17695        EL PASO
# 27                   Associate Auctioneer  17696         POTTER
# 28                   Associate Auctioneer  17699        EL PASO
# 29                   Associate Auctioneer  17706        GRAYSON
# ...                                   ...    ...            ...
# 597785  Water Well Driller/Pump Installer  59847     MONTGOMERY
# 597786  Water Well Driller/Pump Installer  59856          BEXAR
# 597787  Water Well Driller/Pump Installer  59857     DEAF SMITH
# 597788  Water Well Driller/Pump Installer  59858        MIDLAND
# 597789  Water Well Driller/Pump Installer  59862   OUT OF STATE
# 597790  Water Well Driller/Pump Installer  59877   OUT OF STATE
# 597791  Water Well Driller/Pump Installer  59878        WHEELER
# 597792  Water Well Driller/Pump Installer  59879        MADISON
# 597793  Water Well Driller/Pump Installer  59886        TARRANT
# 597794  Water Well Driller/Pump Installer  59887     DEAF SMITH
# 597795  Water Well Driller/Pump Installer  59889         BURNET
# 597796  Water Well Driller/Pump Installer  59890   OUT OF STATE
# 597797  Water Well Driller/Pump Installer  59892        MIDLAND
# 597798  Water Well Driller/Pump Installer  59896       BREWSTER
# 597799  Water Well Driller/Pump Installer  59901           HAYS
# 597800  Water Well Driller/Pump Installer  59902         DENTON
# 597801  Water Well Driller/Pump Installer  59904         BOSQUE
# 597802  Water Well Driller/Pump Installer  59905           HAYS
# 597803  Water Well Driller/Pump Installer  59907         UVALDE
# 597804  Water Well Driller/Pump Installer  59908  COLLINGSWORTH
# 597805  Water Well Driller/Pump Installer  59911       ATASCOSA
# 597806  Water Well Driller/Pump Installer  59912   OUT OF STATE
# 597807  Water Well Driller/Pump Installer  59913      LIMESTONE
# 597808  Water Well Driller/Pump Installer  59926      HENDERSON
# 597809  Water Well Driller/Pump Installer  59929         BOSQUE
# 597810  Water Well Driller/Pump Installer  59930      TOM GREEN
# 597811  Water Well Driller/Pump Installer  59931        RUNNELS
# 597812  Water Well Driller/Pump Installer  59934         LAVACA
# 597813  Water Well Driller/Pump Installer  59936        HOCKLEY
# 597814  Water Well Driller/Pump Installer  59941         WILSON
#
#               RISINGER, JIM MARVIN  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0              WILLIAMS, JON ANDRE         NaN         NaN         NaN
# 1            GUEVARA, JUAN ANTONIO         NaN         NaN         NaN
# 2         BOWERS, JAMES BRISCOE II         NaN         NaN         NaN
# 3              DEMSKY, JOHN EDWARD         NaN         NaN         NaN
# 4                THOMPSON, RANDY D         NaN         NaN         NaN
# 5               TUCKER, MONTE EARL         NaN         NaN         NaN
# 6             COOPER, THOMAS JAMES         NaN         NaN         NaN
# 7          BLANKENSHIP, KERRY NEIL         NaN         NaN         NaN
# 8           DAWES, NICHOLAS MORGAN         NaN         NaN         NaN
# 9             LESTER, TIMMY EUGENE         NaN         NaN         NaN
# 10             MANCILL, MARK DUANE         NaN         NaN         NaN
# 11          HUDDLESTON, SHAWN ALAN         NaN         NaN         NaN
# 12            JORDAN, JAMES EUGENE         NaN         NaN         NaN
# 13          IRWIN, MICHAEL RICHARD         NaN         NaN         NaN
# 14               HALL, WESLEY RYON         NaN         NaN         NaN
# 15              JAMES, BACHUS ROSS         NaN         NaN         NaN
# 16            SIDAWI, JOSEPH JAMES         NaN         NaN         NaN
# 17              SMITH, DAVID JAMES         NaN         NaN         NaN
# 18            FERGUSON, JACKIE LEE         NaN         NaN         NaN
# 19             MCKINLEY, MATTHEW D         NaN         NaN         NaN
# 20             SOWELL, KALEN BRICE         NaN         NaN         NaN
# 21              SEVIER, VIRGINIA A         NaN         NaN         NaN
# 22               SOMERVILLE, CAL W         NaN         NaN         NaN
# 23          BARCLIFT, AUSTIN TYLER         NaN         NaN         NaN
# 24             FORD, PATRICIA NORA         NaN         NaN         NaN
# 25           SCHAFER, TIMOTHY RYAN         NaN         NaN         NaN
# 26          MARTINEZ, BRANDY MARIE         NaN         NaN         NaN
# 27            CLEMANS, ZACHARY LEE         NaN         NaN         NaN
# 28                MARTINEZ, ARTURO         NaN         NaN         NaN
# 29              CARSON, DAVID WADE         NaN         NaN         NaN
# ...                            ...         ...         ...         ...
# 597785      SNUFFER, KENNETH DAVID         NaN         NaN         NaN
# 597786            MARTINEZ, JUAN R         NaN         NaN         NaN
# 597787        YOSTEN, BLAKE JOSEPH         NaN         NaN         NaN
# 597788           CLICK, JAY MARCUS         NaN         NaN         NaN
# 597789          PENSE, LARRY WAYNE         NaN         NaN         NaN
# 597790              LARA, STEVEN D         NaN         NaN         NaN
# 597791               SMITH, JACE E         NaN         NaN         NaN
# 597792    BINNICKER, RICHARD ALLEN         NaN         NaN         NaN
# 597793    CHAVEZ, FRANCISCO JAVIER         NaN         NaN         NaN
# 597794             GUERRERO, REY S         NaN         NaN         NaN
# 597795  SAVAGE, CROCKETT NATHANIEL         NaN         NaN         NaN
# 597796              ADAMS, AARON J         NaN         NaN         NaN
# 597797              SCOTT, JAMES A         NaN         NaN         NaN
# 597798             HILL, RYAN WADE         NaN         NaN         NaN
# 597799         THOMPSON, JARED W T         NaN         NaN         NaN
# 597800        THOMAS, WESLEY WAYNE         NaN         NaN         NaN
# 597801      JURGENSEN, JOSHUA MARK         NaN         NaN         NaN
# 597802         MARSH, AARON ANDREW         NaN         NaN         NaN
# 597803       KILLOUGH, BRUCE WAYNE         NaN         NaN         NaN
# 597804        FAULKS, CARSON SLADE         NaN         NaN         NaN
# 597805    ATKINS, BRANDON BUCHANAN         NaN         NaN         NaN
# 597806            WILLIAMS, MARC R         NaN         NaN         NaN
# 597807      WINSTEAD, CLINTON WADE         NaN         NaN         NaN
# 597808             LILLEY, CLINTON         NaN         NaN         NaN
# 597809              WOODS, JACOB R         NaN         NaN         NaN
# 597810              ABEL, JUSTIN C         NaN         NaN         NaN
# 597811         GRAY, MATTHEW BRYAN         NaN         NaN         NaN
# 597812              MAYER, DAVID W         NaN         NaN         NaN
# 597813     FRIESEN, FRANCISCO FEHR         NaN         NaN         NaN
# 597814              BAUER, DAVID A         NaN         NaN         NaN
#
#         Unnamed: 7  08102017      RISINGER, JIM MARVIN.1  \
# 0              NaN  12292017         WILLIAMS, JON ANDRE
# 1              NaN   9262017       GUEVARA, JUAN ANTONIO
# 2              NaN  11042017    BOWERS, JAMES BRISCOE II
# 3              NaN   2252018         DEMSKY, JOHN EDWARD
# 4              NaN   5042017           THOMPSON, RANDY D
# 5              NaN   6162017          TUCKER, MONTE EARL
# 6              NaN   3182017        COOPER, THOMAS JAMES
# 7              NaN   5042017     BLANKENSHIP, KERRY NEIL
# 8              NaN  10192017      DAWES, NICHOLAS MORGAN
# 9              NaN   8192017        LESTER, TIMMY EUGENE
# 10             NaN   4212017         MANCILL, MARK DUANE
# 11             NaN   2182017      HUDDLESTON, SHAWN ALAN
# 12             NaN   2182018        JORDAN, JAMES EUGENE
# 13             NaN   2252017      IRWIN, MICHAEL RICHARD
# 14             NaN   1252018           HALL, WESLEY RYON
# 15             NaN   5042017          JAMES, BACHUS ROSS
# 16             NaN   2082017        SIDAWI, JOSEPH JAMES
# 17             NaN   2082018          SMITH, DAVID JAMES
# 18             NaN   2092018        FERGUSON, JACKIE LEE
# 19             NaN   2182018         MCKINLEY, MATTHEW D
# 20             NaN   2182018         SOWELL, KALEN BRICE
# 21             NaN   2252018          SEVIER, VIRGINIA A
# 22             NaN   2252017           SOMERVILLE, CAL W
# 23             NaN   3172018      BARCLIFT, AUSTIN TYLER
# 24             NaN   3182017         FORD, PATRICIA NORA
# 25             NaN   4012017       SCHAFER, TIMOTHY RYAN
# 26             NaN   4112017      MARTINEZ, BRANDY MARIE
# 27             NaN   4112017        CLEMANS, ZACHARY LEE
# 28             NaN   4182017            MARTINEZ, ARTURO
# 29             NaN   4252017          CARSON, DAVID WADE
# ...            ...       ...                         ...
# 597785         NaN   9162017      SNUFFER, KENNETH DAVID
# 597786         NaN   9192017            MARTINEZ, JUAN R
# 597787         NaN   9192017        YOSTEN, BLAKE JOSEPH
# 597788         NaN   9202017           CLICK, JAY MARCUS
# 597789         NaN   9222017          PENSE, LARRY WAYNE
# 597790         NaN  10042017              LARA, STEVEN D
# 597791         NaN  10062017               SMITH, JACE E
# 597792         NaN  10062017    BINNICKER, RICHARD ALLEN
# 597793         NaN  10172017    CHAVEZ, FRANCISCO JAVIER
# 597794         NaN  10172017             GUERRERO, REY S
# 597795         NaN  10192017  SAVAGE, CROCKETT NATHANIEL
# 597796         NaN  10192017              ADAMS, AARON J
# 597797         NaN  10312017              SCOTT, JAMES A
# 597798         NaN  11142017             HILL, RYAN WADE
# 597799         NaN  11222017         THOMPSON, JARED W T
# 597800         NaN  11282017        THOMAS, WESLEY WAYNE
# 597801         NaN  11292017      JURGENSEN, JOSHUA MARK
# 597802         NaN  12012017         MARSH, AARON ANDREW
# 597803         NaN  12052017       KILLOUGH, BRUCE WAYNE
# 597804         NaN  12062017        FAULKS, CARSON SLADE
# 597805         NaN  12132017    ATKINS, BRANDON BUCHANAN
# 597806         NaN  12152017            WILLIAMS, MARC R
# 597807         NaN  12262017      WINSTEAD, CLINTON WADE
# 597808         NaN   1132018             LILLEY, CLINTON
# 597809         NaN   1232018              WOODS, JACOB R
# 597810         NaN   1232018              ABEL, JUSTIN C
# 597811         NaN   1232018         GRAY, MATTHEW BRYAN
# 597812         NaN   1272018              MAYER, DAVID W
# 597813         NaN   2132018     FRIESEN, FRANCISCO FEHR
# 597814         NaN   2162018              BAUER, DAVID A
#
#                     7668 S US HWY 59 Unnamed: 11  \
# 0                        228 FM 1252         NaN
# 1                       6909 HWY 181         NaN
# 2                     6767 NORTH FWY         NaN
# 3                     130 E CLARK ST         NaN
# 4                10995 BELLEVILLE RD         NaN
# 5                    19139 HIGHWAY 6         NaN
# 6                        346 MAIN ST         NaN
# 7                10664 BELLEVILLE RD         NaN
# 8       3500 MAPLE AVENUE 17TH FLOOR         NaN
# 9              167 COUNTY ROAD 16380         NaN
# 10                 116 TRAILWOOD CIR         NaN
# 11                3903 EISENHOUER RD         NaN
# 12                     6190 CARGO RD         NaN
# 13            8513 MICHAEL TALTY AVE         NaN
# 14                      13016 HWY 36         NaN
# 15                   471 N HARBIN DR         NaN
# 16                     2032 W FM 917         NaN
# 17           1110 US HIGHWAY 84 WEST         NaN
# 18                     119 E KYLE ST         NaN
# 19                  805 BROADWAY AVE         NaN
# 20                 111 N BROADWAY ST         NaN
# 21                      212 S ROGERS         NaN
# 22                   202 BRANDY LOOP         NaN
# 23                        119 E KYLE         NaN
# 24                   1414 ATLANTA ST         NaN
# 25              12449 US HIGHWAY 385         NaN
# 26                 7120 ALTO REY AVE         NaN
# 27                   2520 CLIMER CIR         NaN
# 28                 7120 ALTO REY AVE         NaN
# 29                1510 S COLLINS FWY         NaN
# ...                              ...         ...
# 597785            13895 E FM 1097 RD         NaN
# 597786               4412 BLUEMEL RD         NaN
# 597787             608 N 25 MILE AVE         NaN
# 597788                   9701 FM 307         NaN
# 597789                654 W 138TH ST         NaN
# 597790    3922 E UNIVERSITY DR STE 1         NaN
# 597791                  8550 FM 3182         NaN
# 597792              103 S MADISON ST         NaN
# 597793                2415 CULLEN ST         NaN
# 597794                    PO BOX 871         NaN
# 597795                  1351 FM 1980         NaN
# 597796    3922 E UNIVERSITY DR STE 1         NaN
# 597797        415 W WALL ST STE 1300         NaN
# 597798                   5010 TED ST         NaN
# 597799             185 ANGEL FIRE RD         NaN
# 597800          15035 US HIGHWAY 287         NaN
# 597801             18099 N HIGHWAY 6         NaN
# 597802           31866 RANCH ROAD 12         NaN
# 597803                   428 MAIN ST         NaN
# 597804                  4243 FM 1547         NaN
# 597805              1209 BENSDALE RD         NaN
# 597806    3922 E UNIVERSITY DR STE 1         NaN
# 597807        151 PRIVATE ROAD 5762B         NaN
# 597808           1301 E CORSICANA ST         NaN
# 597809             18099 N HIGHWAY 6         NaN
# 597810           6601 RM HIGHWAY 853         NaN
# 597811                 401 VICTOR ST         NaN
# 597812                  966 FM 318 E         NaN
# 597813               3686 JAMAICA RD         NaN
# 597814                2590 HEINEN RD         NaN
#
#                   NACOGDOCHES TX 75964   0347    NACOGDOCHES  75964  \
# 0                     KILGORE TX 75662  183.0          GREGG  75662
# 1                        POTH TX 78147  493.0         WILSON  78147
# 2                HOUSTON TX 77076-2027  201.0         HARRIS  77076
# 3                    BARTLETT TX 76511   27.0           BELL  76511
# 4                    RINGLING OK 73456  999.0   OUT OF STATE  73456
# 5                  SAYRE OK 73662-6080  999.0   OUT OF STATE  73662
# 6                     ROSEBUD TX 76570  145.0          FALLS  76570
# 7               RINGLING OK 73456-2014  999.0   OUT OF STATE  73456
# 8                      DALLAS TX 75219  113.0         DALLAS  75219
# 9                  CUNNINGHAM TX 75434  277.0          LAMAR  75434
# 10                LUFKIN TX 75904-4331    5.0       ANGELINA  75904
# 11                SAN ANTONIO TX 78218   29.0          BEXAR  78218
# 12                     ODESSA TX 79762  135.0          ECTOR  79762
# 13               TERRELL TX 75160-7592  257.0        KAUFMAN  75160
# 14              COMANCHE TX 76442-7305   93.0       COMANCHE  76442
# 15          STEPHENVILLE TX 76401-2860  143.0          ERATH  76401
# 16                JOSHUA TX 76058-6060  251.0        JOHNSON  76058
# 17                GOLDTHWAITE TX 76844  333.0          MILLS  76844
# 18                      BANGS TX 76823   49.0          BROWN  76823
# 19            GLADEWATER TX 75647-2415  183.0          GREGG  75647
# 20                    CRESSON TX 76035  221.0           HOOD  76035
# 21                 WAXAHACHIE TX 75165  139.0          ELLIS  75165
# 22               KILLEEN TX 76549-9049   27.0           BELL  76549
# 23                      BANGS TX 76823   49.0          BROWN  76823
# 24             DEER PARK TX 77536-4704  201.0         HARRIS  77536
# 25                    DALHART TX 79022  111.0         DALLAM  79022
# 26               EL PASO TX 79912-2104  141.0        EL PASO  79912
# 27              AMARILLO TX 79124-2319  375.0         POTTER  79124
# 28               EL PASO TX 79912-2104  141.0        EL PASO  79912
# 29                  HOWE TX 75459-4752  181.0        GRAYSON  75459
# ...                                ...    ...            ...    ...
# 597785            WILLIS TX 77378-4347  339.0     MONTGOMERY  77378
# 597786       SAN ANTONIO TX 78240-1007   29.0          BEXAR  78240
# 597787          HEREFORD TX 79045-3020  117.0     DEAF SMITH  79045
# 597788           MIDLAND TX 79706-5112  329.0        MIDLAND  79706
# 597789          GLENPOOL OK 74033-3445  999.0   OUT OF STATE  74033
# 597790           PHOENIX AZ 85034-2208  999.0   OUT OF STATE  85034
# 597791          MOBEETIE TX 79061-4701  483.0        WHEELER  79061
# 597792      MADISONVILLE TX 77864-1902  313.0        MADISON  77864
# 597793        FORT WORTH TX 76107-1411  439.0        TARRANT  76107
# 597794          HEREFORD TX 79045-0871  117.0     DEAF SMITH  79045
# 597795      MARBLE FALLS TX 78654-7385   53.0         BURNET  78654
# 597796           PHOENIX AZ 85034-2208  999.0   OUT OF STATE  85034
# 597797           MIDLAND TX 79701-4417  329.0        MIDLAND  79701
# 597798            ALPINE TX 79830-1049   43.0       BREWSTER  79830
# 597799  DRIPPING SPRINGS TX 78620-2477  209.0           HAYS  78620
# 597800             BOWIE TX 76230-5969  337.0       MONTAGUE  76230
# 597801      VALLEY MILLS TX 76689-2963   35.0         BOSQUE  76689
# 597802  DRIPPING SPRINGS TX 78620-4097  209.0           HAYS  78620
# 597803            UTOPIA TX 78884-2602  463.0         UVALDE  78884
# 597804             QUAIL TX 79251-4126   87.0  COLLINGSWORTH  79251
# 597805        PLEASANTON TX 78064-1733   13.0       ATASCOSA  78064
# 597806           PHOENIX AZ 85034-2208  999.0   OUT OF STATE  85034
# 597807         GROESBECK TX 76642-2304  293.0      LIMESTONE  76642
# 597808            ATHENS TX 75751-2236  213.0      HENDERSON  75751
# 597809      VALLEY MILLS TX 76689-2963   35.0         BOSQUE  76689
# 597810        SAN ANGELO TX 76901-9716  451.0      TOM GREEN  76901
# 597811            ROWENA TX 76875-2608  399.0        RUNNELS  76875
# 597812            YOAKUM TX 77995-6786  285.0         LAVACA  77995
# 597813         LEVELLAND TX 79336-9124  219.0        HOCKLEY  79336
# 597814       FLORESVILLE TX 78114-6076  493.0         WILSON  78114
#
#          9363665745 Unnamed: 17  N
# 0        9039187899         NaN  N
# 1               NaN         NaN  N
# 2        7136445566         NaN  N
# 3        2549852228         NaN  N
# 4        5802765961         NaN  N
# 5        5802250269         NaN  N
# 6        2815078713         NaN  N
# 7        5802765961         NaN  N
# 8        2144091137         NaN  N
# 9        9037825759         NaN  N
# 10       9366749636         NaN  N
# 11       2106815425         NaN  N
# 12       4322722266         NaN  N
# 13       4695951384         NaN  N
# 14       3253565950         NaN  N
# 15       2545928394         NaN  N
# 16       8173200833         NaN  N
# 17       3259386750         NaN  N
# 18       3253727333         NaN  N
# 19       9038453830         NaN  N
# 20       8173821530         NaN  N
# 21       9726930572         NaN  N
# 22       2542893216         NaN  N
# 23       3253727333         NaN  N
# 24       2814797848         NaN  N
# 25       8062446776         NaN  N
# 26       9153733887         NaN  N
# 27       8066833130         NaN  N
# 28       9153733887         NaN  N
# 29       9035325501         NaN  N
# ...             ...         ... ..
# 597785  9.36857e+09           W  N
# 597786  2.10698e+09           M  N
# 597787  8.06365e+09          KP  N
# 597788  4.32682e+09           W  N
# 597789  9.18322e+09           W  N
# 597790  6.02453e+09           M  N
# 597791  8.06827e+09        KLPT  N
# 597792  9.36349e+09          PW  N
# 597793  8.17877e+09           M  N
# 597794  8.06364e+09        KLPT  N
# 597795  8.30693e+09           P  N
# 597796  6.02453e+09           M  N
# 597797  4.32558e+09           W  N
# 597798  4.32294e+09         KLP  N
# 597799  5.12894e+09          KP  N
# 597800  9.40873e+09           W  N
# 597801  2.54933e+09         KPT  N
# 597802  5.12858e+09           P  N
# 597803  8.30966e+09          KP  N
# 597804  8.06898e+09       KLPTW  N
# 597805  8.30281e+09         KPT  N
# 597806  6.02453e+09           M  N
# 597807  2.54729e+09           W  N
# 597808  9.03675e+09         KLP  N
# 597809  2.54933e+09           P  N
# 597810   3.2595e+09          KP  N
# 597811  3.25442e+09        KLPW  N
# 597812  3.61293e+09           P  N
# 597813  8.06598e+09           W  N
# 597814  8.30392e+09           W  N
#
# [597815 rows x 19 columns]

# %% [markdown]
# ## 2. That looks terrible, let's add column names.
#
# It apparently doesn't have headers! **Read the file in again, but setting your own column names**. Their [current data dictionary might not perfectly match](https://www.opendatanetwork.com/dataset/data.texas.gov/7358-krk7), but you can use it to understand what the columns are. For the dataset we're using, the order goes like this:
#
# * LICTYPE
# * LICNUMBER
# * BIZCOUNTY
# * BIZNAME
# * BIZLINE1
# * BIZLINE2
# * BIZCITYSTATE
# * BIZTELEPHONE
# * EXPIRATION
# * OWNER
# * MAILLINE1
# * MAILLINE2
# * MAILCITYSTATE
# * MAILCOUNTYCODE
# * MAILCOUNTY
# * MAILZIP
# * TELEPHONE
# * LICSUBTYPE
# * CEFLAG
#
# **Note:** You can rename the columns to things that make sense - "expiration" is a little more manageable than "LICENSE EXPIRATION DATE (MMDDCCYY)". I've named my License Type column LICTYPE, so if you haven't you'll have to change the rest of my sample code to match.

# %%
df.columns = ['LICTYPE',
'LICNUMBER',
'BIZCOUNTY',
'BIZNAME',
'BIZLINE1',
'BIZLINE2',
'BIZCITYSTATE',
'BIZTELEPHONE',
'EXPIRATION',
'OWNER',
'MAILLINE1',
'MAILLINE2',
'MAILCITYSTATE',
'MAILCOUNTYCODE',
'MAILCOUNTY',
'MAILZIP',
'TELEPHONE',
'LICSUBTYPE',
'CEFLAG']

# %% [markdown]
# # 3. Force string columns to be strings
#
# The county code and expiration dates are being read in as numbers, which is going to cause some trouble later on. You can force a column to be a certain type (most usually strings) when reading it in with the following code:
#
#     df = pd.read_csv("your-filename.csv", dtype={"colname1": str, "colname2": str})
#
# You don't need to do it for every column, just the ones you want to force!
#
# **Re-import the file, forcing the expiration date, license number, mailing address county code, mailing zip code and telephone to all be strings.**

# %%
df = pd.read_csv("licfile.csv", dtype= str)

df.columns = ['LICTYPE',
'LICNUMBER',
'BIZCOUNTY',
'BIZNAME',
'BIZLINE1',
'BIZLINE2',
'BIZCITYSTATE',
'BIZTELEPHONE',
'EXPIRATION',
'OWNER',
'MAILLINE1',
'MAILLINE2',
'MAILCITYSTATE',
'MAILCOUNTYCODE',
'MAILCOUNTY',
'MAILZIP',
'TELEPHONE',
'LICSUBTYPE',
'CEFLAG']

# %% [markdown]
# Check the data types of your columns to be sure! If you do it right they'll be `object` (not `str`, oddly).

# %%
df.dtypes
# Out:
# LICTYPE           object
# LICNUMBER         object
# BIZCOUNTY         object
# BIZNAME           object
# BIZLINE1          object
# BIZLINE2          object
# BIZCITYSTATE      object
# BIZTELEPHONE      object
# EXPIRATION        object
# OWNER             object
# MAILLINE1         object
# MAILLINE2         object
# MAILCITYSTATE     object
# MAILCOUNTYCODE    object
# MAILCOUNTY        object
# MAILZIP           object
# TELEPHONE         object
# LICSUBTYPE        object
# CEFLAG            object
# dtype: object

# %% [markdown]
# ## 4. Convert those expiration dates from MMDDYYYY to YYYY-MM-DD
#
# List slicing forever! It's the thing with the `[]`. There are like five ways to do this one.

# %%
dates = df['EXPIRATION']

dates
    
date_list = []

for date in dates:
    date_list.append(f'[{date}]')

print(date_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Check the first five expirations to make sure they look right.

# %%
#Jupyter Notebook says the data rate has been exceeded???

# %% [markdown]
# # PART TWO: LOOKING AT LICENSES

# %% [markdown]
# ## 5. What are the top 10 most common licenses?

# %%
df['LICTYPE'].value_counts(normalize = True).head(10)
# Out:
# Cosmetology Operator        0.255965
# Apprentice Electrician      0.187214
# Cosmetology Manicurist      0.083901
# Journeyman Electrician      0.064615
# A/C Technician              0.047330
# Cosmetology Esthetician     0.039973
# Cosmetology Beauty Salon    0.039912
# Master Electrician          0.028456
# A/C Contractor              0.027722
# Barber, Class A             0.027117
# Name: LICTYPE, dtype: float64

# %% [markdown]
# ## 6. What are the top 10 least common?

# %%
df['LICTYPE'].value_counts(normalize = True).tail(10)
# Out:
# Elevator Responsible Party CE Provider             0.000014
# Mobile Cosmetology Esthetician Specialty Saloon    0.000008
# Barber Hair Braiding Shop                          0.000007
# Barber Hair Weaving Shop                           0.000007
# Booting CE Provider                                0.000005
# Mobile Cosmetology Manicure Specialty Saloon       0.000003
# Cosmetology Wig Instructor                         0.000003
# Licensed Court Interpreter CE Provider             0.000003
# Mobile Cosmetology Esthetician/Manicure Saloon     0.000003
# Legal Service Contract Admin                       0.000002
# Name: LICTYPE, dtype: float64

# %% [markdown]
# ## 7. Try to select everyone who is any type of electrician.
#
# You're going to get an error about `"cannot index with vector containing NA / NaN values"`. Let's work our way in there.

# %%
# Yes I know I left this in here, it's a learning experience!
df[df['LICTYPE'].str.contains("Electrician")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b38669659b4f> in <module>
#       1 # Yes I know I left this in here, it's a learning experience!
# ----> 2 df[df['LICTYPE'].str.contains("Electrician")]
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
# -> 2917         if com.is_bool_indexer(key):
#    2918             return self._getitem_bool_array(key)
#    2919
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     122             if not lib.is_bool_array(key):
#     123                 if isna(key).any():
# --> 124                     raise ValueError(na_msg)
#     125                 return False
#     126             return True
#
# ValueError: cannot index with vector containing NA / NaN values

# %% [markdown]
# ## 8. How many of the rows of LICTYPE are NaN?

# %%
df['LICTYPE'].isnull().value_counts()

# %% [markdown]
# Over 7000 licenses don't have types! As a result, when we look for license types with electricians - aka do `df['LICTYPE'].str.contains("Electrician")` - we get three results:
#
# * `True` means `LICTYPE` exists and contains `"Electrician"`
# * `False` means `LICTYPE` exists and does not contain `"Electrician"`
# * `NaN` means `LICTYPE` does not exist for that row

# %% [markdown]
# ## 9. Actually getting everyone who is an electrician

# %% [markdown]
# This doesn't work when trying to select electricians, though, as NaN is a no-go for a filter. We *could* filter out everywhere the LICTYPE is null, but we could also cheat a little and say "replace all of the `NaN` values with `False` values."
#
# `.fillna(False)` will take every `NaN` and replace it with `False`.

# %%
df['LICTYPE'] = df['LICTYPE'].fillna(0, inplace=True)

# %% [markdown]
# ## 10. What's the most popular kind of electrician?

# %%
df[df['LICTYPE'].isnull()]

# %%
df['LICTYPE'].astype('str')

# %%
df[df['LICTYPE'].str.contains("Electrician")]

# %% [markdown]
# ## 11. Graph it, with the largest bar on top.

# %%
# previous code not working

# %% [markdown]
# ## 12. How many sign electricians are there?
#
# There are a few ways to do this one.

# %%
# previous code not working

# %% [markdown]
# # PART THREE: LOOKING AT LAST NAMES

# %% [markdown]
# ## 13. Extract every owner's last name
#
# You want everything before the comma. We've done this before (in a few different ways!).
#
# * **Hint:** If you get an error about missing or `NaN` data, you might use `.fillna('')` to replace every empty owner name with an empty string. This might not happen to you, though, depending on how you do it!
#
# * **Hint:** You probably want to do `expand=False` on your extraction to make sure it comes out as a series instead of a dataframe.

# %%
df['BIZNAME'].str.split(",").str.get(0)
# Out:
# 0            WILLIAMS
# 1             GUEVARA
# 2              BOWERS
# 3              DEMSKY
# 4            THOMPSON
# 5              TUCKER
# 6              COOPER
# 7         BLANKENSHIP
# 8               DAWES
# 9              LESTER
# 10            MANCILL
# 11         HUDDLESTON
# 12             JORDAN
# 13              IRWIN
# 14               HALL
# 15              JAMES
# 16             SIDAWI
# 17              SMITH
# 18           FERGUSON
# 19           MCKINLEY
# 20             SOWELL
# 21             SEVIER
# 22         SOMERVILLE
# 23           BARCLIFT
# 24               FORD
# 25            SCHAFER
# 26           MARTINEZ
# 27            CLEMANS
# 28           MARTINEZ
# 29             CARSON
#              ...
# 597785        SNUFFER
# 597786       MARTINEZ
# 597787         YOSTEN
# 597788          CLICK
# 597789          PENSE
# 597790           LARA
# 597791          SMITH
# 597792      BINNICKER
# 597793         CHAVEZ
# 597794       GUERRERO
# 597795         SAVAGE
# 597796          ADAMS
# 597797          SCOTT
# 597798           HILL
# 597799       THOMPSON
# 597800         THOMAS
# 597801      JURGENSEN
# 597802          MARSH
# 597803       KILLOUGH
# 597804         FAULKS
# 597805         ATKINS
# 597806       WILLIAMS
# 597807       WINSTEAD
# 597808         LILLEY
# 597809          WOODS
# 597810           ABEL
# 597811           GRAY
# 597812          MAYER
# 597813        FRIESEN
# 597814          BAUER
# Name: BIZNAME, Length: 597815, dtype: object

# %% [markdown]
# ## 14. Save the last name into a new column
#
# Then check to make sure it exists, and you successfully saved it into the dataframe.

# %%
df['last_name'] = df['BIZNAME'].str.split(",").str.get(0)

# %%
df
# Out:
#                                   LICTYPE LICNUMBER      BIZCOUNTY  \
# 0                    Associate Auctioneer      7962         UPSHUR
# 1                    Associate Auctioneer      8406         WILSON
# 2                    Associate Auctioneer     10543         HARRIS
# 3                    Associate Auctioneer     10642           BELL
# 4                    Associate Auctioneer     15650   OUT OF STATE
# 5                    Associate Auctioneer     15698   OUT OF STATE
# 6                    Associate Auctioneer     15810          MILAM
# 7                    Associate Auctioneer     15835   OUT OF STATE
# 8                    Associate Auctioneer     16784   OUT OF STATE
# 9                    Associate Auctioneer     16893          LAMAR
# 10                   Associate Auctioneer     16969    NACOGDOCHES
# 11                   Associate Auctioneer     16990          BEXAR
# 12                   Associate Auctioneer     17072          ECTOR
# 13                   Associate Auctioneer     17108        KAUFMAN
# 14                   Associate Auctioneer     17241           HOOD
# 15                   Associate Auctioneer     17242          ERATH
# 16                   Associate Auctioneer     17669        JOHNSON
# 17                   Associate Auctioneer     17671          MILLS
# 18                   Associate Auctioneer     17672          BROWN
# 19                   Associate Auctioneer     17675         UPSHUR
# 20                   Associate Auctioneer     17676        JOHNSON
# 21                   Associate Auctioneer     17679          ELLIS
# 22                   Associate Auctioneer     17680           BELL
# 23                   Associate Auctioneer     17685       SAN SABA
# 24                   Associate Auctioneer     17687         HARRIS
# 25                   Associate Auctioneer     17689         DALLAM
# 26                   Associate Auctioneer     17695        EL PASO
# 27                   Associate Auctioneer     17696         POTTER
# 28                   Associate Auctioneer     17699        EL PASO
# 29                   Associate Auctioneer     17706        GRAYSON
# ...                                   ...       ...            ...
# 597785  Water Well Driller/Pump Installer     59847     MONTGOMERY
# 597786  Water Well Driller/Pump Installer     59856          BEXAR
# 597787  Water Well Driller/Pump Installer     59857     DEAF SMITH
# 597788  Water Well Driller/Pump Installer     59858        MIDLAND
# 597789  Water Well Driller/Pump Installer     59862   OUT OF STATE
# 597790  Water Well Driller/Pump Installer     59877   OUT OF STATE
# 597791  Water Well Driller/Pump Installer     59878        WHEELER
# 597792  Water Well Driller/Pump Installer     59879        MADISON
# 597793  Water Well Driller/Pump Installer     59886        TARRANT
# 597794  Water Well Driller/Pump Installer     59887     DEAF SMITH
# 597795  Water Well Driller/Pump Installer     59889         BURNET
# 597796  Water Well Driller/Pump Installer     59890   OUT OF STATE
# 597797  Water Well Driller/Pump Installer     59892        MIDLAND
# 597798  Water Well Driller/Pump Installer     59896       BREWSTER
# 597799  Water Well Driller/Pump Installer     59901           HAYS
# 597800  Water Well Driller/Pump Installer     59902         DENTON
# 597801  Water Well Driller/Pump Installer     59904         BOSQUE
# 597802  Water Well Driller/Pump Installer     59905           HAYS
# 597803  Water Well Driller/Pump Installer     59907         UVALDE
# 597804  Water Well Driller/Pump Installer     59908  COLLINGSWORTH
# 597805  Water Well Driller/Pump Installer     59911       ATASCOSA
# 597806  Water Well Driller/Pump Installer     59912   OUT OF STATE
# 597807  Water Well Driller/Pump Installer     59913      LIMESTONE
# 597808  Water Well Driller/Pump Installer     59926      HENDERSON
# 597809  Water Well Driller/Pump Installer     59929         BOSQUE
# 597810  Water Well Driller/Pump Installer     59930      TOM GREEN
# 597811  Water Well Driller/Pump Installer     59931        RUNNELS
# 597812  Water Well Driller/Pump Installer     59934         LAVACA
# 597813  Water Well Driller/Pump Installer     59936        HOCKLEY
# 597814  Water Well Driller/Pump Installer     59941         WILSON
#
#                            BIZNAME BIZLINE1 BIZLINE2 BIZCITYSTATE  \
# 0              WILLIAMS, JON ANDRE      NaN      NaN          NaN
# 1            GUEVARA, JUAN ANTONIO      NaN      NaN          NaN
# 2         BOWERS, JAMES BRISCOE II      NaN      NaN          NaN
# 3              DEMSKY, JOHN EDWARD      NaN      NaN          NaN
# 4                THOMPSON, RANDY D      NaN      NaN          NaN
# 5               TUCKER, MONTE EARL      NaN      NaN          NaN
# 6             COOPER, THOMAS JAMES      NaN      NaN          NaN
# 7          BLANKENSHIP, KERRY NEIL      NaN      NaN          NaN
# 8           DAWES, NICHOLAS MORGAN      NaN      NaN          NaN
# 9             LESTER, TIMMY EUGENE      NaN      NaN          NaN
# 10             MANCILL, MARK DUANE      NaN      NaN          NaN
# 11          HUDDLESTON, SHAWN ALAN      NaN      NaN          NaN
# 12            JORDAN, JAMES EUGENE      NaN      NaN          NaN
# 13          IRWIN, MICHAEL RICHARD      NaN      NaN          NaN
# 14               HALL, WESLEY RYON      NaN      NaN          NaN
# 15              JAMES, BACHUS ROSS      NaN      NaN          NaN
# 16            SIDAWI, JOSEPH JAMES      NaN      NaN          NaN
# 17              SMITH, DAVID JAMES      NaN      NaN          NaN
# 18            FERGUSON, JACKIE LEE      NaN      NaN          NaN
# 19             MCKINLEY, MATTHEW D      NaN      NaN          NaN
# 20             SOWELL, KALEN BRICE      NaN      NaN          NaN
# 21              SEVIER, VIRGINIA A      NaN      NaN          NaN
# 22               SOMERVILLE, CAL W      NaN      NaN          NaN
# 23          BARCLIFT, AUSTIN TYLER      NaN      NaN          NaN
# 24             FORD, PATRICIA NORA      NaN      NaN          NaN
# 25           SCHAFER, TIMOTHY RYAN      NaN      NaN          NaN
# 26          MARTINEZ, BRANDY MARIE      NaN      NaN          NaN
# 27            CLEMANS, ZACHARY LEE      NaN      NaN          NaN
# 28                MARTINEZ, ARTURO      NaN      NaN          NaN
# 29              CARSON, DAVID WADE      NaN      NaN          NaN
# ...                            ...      ...      ...          ...
# 597785      SNUFFER, KENNETH DAVID      NaN      NaN          NaN
# 597786            MARTINEZ, JUAN R      NaN      NaN          NaN
# 597787        YOSTEN, BLAKE JOSEPH      NaN      NaN          NaN
# 597788           CLICK, JAY MARCUS      NaN      NaN          NaN
# 597789          PENSE, LARRY WAYNE      NaN      NaN          NaN
# 597790              LARA, STEVEN D      NaN      NaN          NaN
# 597791               SMITH, JACE E      NaN      NaN          NaN
# 597792    BINNICKER, RICHARD ALLEN      NaN      NaN          NaN
# 597793    CHAVEZ, FRANCISCO JAVIER      NaN      NaN          NaN
# 597794             GUERRERO, REY S      NaN      NaN          NaN
# 597795  SAVAGE, CROCKETT NATHANIEL      NaN      NaN          NaN
# 597796              ADAMS, AARON J      NaN      NaN          NaN
# 597797              SCOTT, JAMES A      NaN      NaN          NaN
# 597798             HILL, RYAN WADE      NaN      NaN          NaN
# 597799         THOMPSON, JARED W T      NaN      NaN          NaN
# 597800        THOMAS, WESLEY WAYNE      NaN      NaN          NaN
# 597801      JURGENSEN, JOSHUA MARK      NaN      NaN          NaN
# 597802         MARSH, AARON ANDREW      NaN      NaN          NaN
# 597803       KILLOUGH, BRUCE WAYNE      NaN      NaN          NaN
# 597804        FAULKS, CARSON SLADE      NaN      NaN          NaN
# 597805    ATKINS, BRANDON BUCHANAN      NaN      NaN          NaN
# 597806            WILLIAMS, MARC R      NaN      NaN          NaN
# 597807      WINSTEAD, CLINTON WADE      NaN      NaN          NaN
# 597808             LILLEY, CLINTON      NaN      NaN          NaN
# 597809              WOODS, JACOB R      NaN      NaN          NaN
# 597810              ABEL, JUSTIN C      NaN      NaN          NaN
# 597811         GRAY, MATTHEW BRYAN      NaN      NaN          NaN
# 597812              MAYER, DAVID W      NaN      NaN          NaN
# 597813     FRIESEN, FRANCISCO FEHR      NaN      NaN          NaN
# 597814              BAUER, DAVID A      NaN      NaN          NaN
#
#        BIZTELEPHONE EXPIRATION                       OWNER  \
# 0               NaN   12292017         WILLIAMS, JON ANDRE
# 1               NaN   09262017       GUEVARA, JUAN ANTONIO
# 2               NaN   11042017    BOWERS, JAMES BRISCOE II
# 3               NaN   02252018         DEMSKY, JOHN EDWARD
# 4               NaN   05042017           THOMPSON, RANDY D
# 5               NaN   06162017          TUCKER, MONTE EARL
# 6               NaN   03182017        COOPER, THOMAS JAMES
# 7               NaN   05042017     BLANKENSHIP, KERRY NEIL
# 8               NaN   10192017      DAWES, NICHOLAS MORGAN
# 9               NaN   08192017        LESTER, TIMMY EUGENE
# 10              NaN   04212017         MANCILL, MARK DUANE
# 11              NaN   02182017      HUDDLESTON, SHAWN ALAN
# 12              NaN   02182018        JORDAN, JAMES EUGENE
# 13              NaN   02252017      IRWIN, MICHAEL RICHARD
# 14              NaN   01252018           HALL, WESLEY RYON
# 15              NaN   05042017          JAMES, BACHUS ROSS
# 16              NaN   02082017        SIDAWI, JOSEPH JAMES
# 17              NaN   02082018          SMITH, DAVID JAMES
# 18              NaN   02092018        FERGUSON, JACKIE LEE
# 19              NaN   02182018         MCKINLEY, MATTHEW D
# 20              NaN   02182018         SOWELL, KALEN BRICE
# 21              NaN   02252018          SEVIER, VIRGINIA A
# 22              NaN   02252017           SOMERVILLE, CAL W
# 23              NaN   03172018      BARCLIFT, AUSTIN TYLER
# 24              NaN   03182017         FORD, PATRICIA NORA
# 25              NaN   04012017       SCHAFER, TIMOTHY RYAN
# 26              NaN   04112017      MARTINEZ, BRANDY MARIE
# 27              NaN   04112017        CLEMANS, ZACHARY LEE
# 28              NaN   04182017            MARTINEZ, ARTURO
# 29              NaN   04252017          CARSON, DAVID WADE
# ...             ...        ...                         ...
# 597785          NaN   09162017      SNUFFER, KENNETH DAVID
# 597786          NaN   09192017            MARTINEZ, JUAN R
# 597787          NaN   09192017        YOSTEN, BLAKE JOSEPH
# 597788          NaN   09202017           CLICK, JAY MARCUS
# 597789          NaN   09222017          PENSE, LARRY WAYNE
# 597790          NaN   10042017              LARA, STEVEN D
# 597791          NaN   10062017               SMITH, JACE E
# 597792          NaN   10062017    BINNICKER, RICHARD ALLEN
# 597793          NaN   10172017    CHAVEZ, FRANCISCO JAVIER
# 597794          NaN   10172017             GUERRERO, REY S
# 597795          NaN   10192017  SAVAGE, CROCKETT NATHANIEL
# 597796          NaN   10192017              ADAMS, AARON J
# 597797          NaN   10312017              SCOTT, JAMES A
# 597798          NaN   11142017             HILL, RYAN WADE
# 597799          NaN   11222017         THOMPSON, JARED W T
# 597800          NaN   11282017        THOMAS, WESLEY WAYNE
# 597801          NaN   11292017      JURGENSEN, JOSHUA MARK
# 597802          NaN   12012017         MARSH, AARON ANDREW
# 597803          NaN   12052017       KILLOUGH, BRUCE WAYNE
# 597804          NaN   12062017        FAULKS, CARSON SLADE
# 597805          NaN   12132017    ATKINS, BRANDON BUCHANAN
# 597806          NaN   12152017            WILLIAMS, MARC R
# 597807          NaN   12262017      WINSTEAD, CLINTON WADE
# 597808          NaN   01132018             LILLEY, CLINTON
# 597809          NaN   01232018              WOODS, JACOB R
# 597810          NaN   01232018              ABEL, JUSTIN C
# 597811          NaN   01232018         GRAY, MATTHEW BRYAN
# 597812          NaN   01272018              MAYER, DAVID W
# 597813          NaN   02132018     FRIESEN, FRANCISCO FEHR
# 597814          NaN   02162018              BAUER, DAVID A
#
#                            MAILLINE1 MAILLINE2  \
# 0                        228 FM 1252       NaN
# 1                       6909 HWY 181       NaN
# 2                     6767 NORTH FWY       NaN
# 3                     130 E CLARK ST       NaN
# 4                10995 BELLEVILLE RD       NaN
# 5                    19139 HIGHWAY 6       NaN
# 6                        346 MAIN ST       NaN
# 7                10664 BELLEVILLE RD       NaN
# 8       3500 MAPLE AVENUE 17TH FLOOR       NaN
# 9              167 COUNTY ROAD 16380       NaN
# 10                 116 TRAILWOOD CIR       NaN
# 11                3903 EISENHOUER RD       NaN
# 12                     6190 CARGO RD       NaN
# 13            8513 MICHAEL TALTY AVE       NaN
# 14                      13016 HWY 36       NaN
# 15                   471 N HARBIN DR       NaN
# 16                     2032 W FM 917       NaN
# 17           1110 US HIGHWAY 84 WEST       NaN
# 18                     119 E KYLE ST       NaN
# 19                  805 BROADWAY AVE       NaN
# 20                 111 N BROADWAY ST       NaN
# 21                      212 S ROGERS       NaN
# 22                   202 BRANDY LOOP       NaN
# 23                        119 E KYLE       NaN
# 24                   1414 ATLANTA ST       NaN
# 25              12449 US HIGHWAY 385       NaN
# 26                 7120 ALTO REY AVE       NaN
# 27                   2520 CLIMER CIR       NaN
# 28                 7120 ALTO REY AVE       NaN
# 29                1510 S COLLINS FWY       NaN
# ...                              ...       ...
# 597785            13895 E FM 1097 RD       NaN
# 597786               4412 BLUEMEL RD       NaN
# 597787             608 N 25 MILE AVE       NaN
# 597788                   9701 FM 307       NaN
# 597789                654 W 138TH ST       NaN
# 597790    3922 E UNIVERSITY DR STE 1       NaN
# 597791                  8550 FM 3182       NaN
# 597792              103 S MADISON ST       NaN
# 597793                2415 CULLEN ST       NaN
# 597794                    PO BOX 871       NaN
# 597795                  1351 FM 1980       NaN
# 597796    3922 E UNIVERSITY DR STE 1       NaN
# 597797        415 W WALL ST STE 1300       NaN
# 597798                   5010 TED ST       NaN
# 597799             185 ANGEL FIRE RD       NaN
# 597800          15035 US HIGHWAY 287       NaN
# 597801             18099 N HIGHWAY 6       NaN
# 597802           31866 RANCH ROAD 12       NaN
# 597803                   428 MAIN ST       NaN
# 597804                  4243 FM 1547       NaN
# 597805              1209 BENSDALE RD       NaN
# 597806    3922 E UNIVERSITY DR STE 1       NaN
# 597807        151 PRIVATE ROAD 5762B       NaN
# 597808           1301 E CORSICANA ST       NaN
# 597809             18099 N HIGHWAY 6       NaN
# 597810           6601 RM HIGHWAY 853       NaN
# 597811                 401 VICTOR ST       NaN
# 597812                  966 FM 318 E       NaN
# 597813               3686 JAMAICA RD       NaN
# 597814                2590 HEINEN RD       NaN
#
#                          MAILCITYSTATE MAILCOUNTYCODE     MAILCOUNTY MAILZIP  \
# 0                     KILGORE TX 75662           0183          GREGG   75662
# 1                        POTH TX 78147           0493         WILSON   78147
# 2                HOUSTON TX 77076-2027           0201         HARRIS   77076
# 3                    BARTLETT TX 76511           0027           BELL   76511
# 4                    RINGLING OK 73456           0999   OUT OF STATE   73456
# 5                  SAYRE OK 73662-6080           0999   OUT OF STATE   73662
# 6                     ROSEBUD TX 76570           0145          FALLS   76570
# 7               RINGLING OK 73456-2014           0999   OUT OF STATE   73456
# 8                      DALLAS TX 75219           0113         DALLAS   75219
# 9                  CUNNINGHAM TX 75434           0277          LAMAR   75434
# 10                LUFKIN TX 75904-4331           0005       ANGELINA   75904
# 11                SAN ANTONIO TX 78218           0029          BEXAR   78218
# 12                     ODESSA TX 79762           0135          ECTOR   79762
# 13               TERRELL TX 75160-7592           0257        KAUFMAN   75160
# 14              COMANCHE TX 76442-7305           0093       COMANCHE   76442
# 15          STEPHENVILLE TX 76401-2860           0143          ERATH   76401
# 16                JOSHUA TX 76058-6060           0251        JOHNSON   76058
# 17                GOLDTHWAITE TX 76844           0333          MILLS   76844
# 18                      BANGS TX 76823           0049          BROWN   76823
# 19            GLADEWATER TX 75647-2415           0183          GREGG   75647
# 20                    CRESSON TX 76035           0221           HOOD   76035
# 21                 WAXAHACHIE TX 75165           0139          ELLIS   75165
# 22               KILLEEN TX 76549-9049           0027           BELL   76549
# 23                      BANGS TX 76823           0049          BROWN   76823
# 24             DEER PARK TX 77536-4704           0201         HARRIS   77536
# 25                    DALHART TX 79022           0111         DALLAM   79022
# 26               EL PASO TX 79912-2104           0141        EL PASO   79912
# 27              AMARILLO TX 79124-2319           0375         POTTER   79124
# 28               EL PASO TX 79912-2104           0141        EL PASO   79912
# 29                  HOWE TX 75459-4752           0181        GRAYSON   75459
# ...                                ...            ...            ...     ...
# 597785            WILLIS TX 77378-4347           0339     MONTGOMERY   77378
# 597786       SAN ANTONIO TX 78240-1007           0029          BEXAR   78240
# 597787          HEREFORD TX 79045-3020           0117     DEAF SMITH   79045
# 597788           MIDLAND TX 79706-5112           0329        MIDLAND   79706
# 597789          GLENPOOL OK 74033-3445           0999   OUT OF STATE   74033
# 597790           PHOENIX AZ 85034-2208           0999   OUT OF STATE   85034
# 597791          MOBEETIE TX 79061-4701           0483        WHEELER   79061
# 597792      MADISONVILLE TX 77864-1902           0313        MADISON   77864
# 597793        FORT WORTH TX 76107-1411           0439        TARRANT   76107
# 597794          HEREFORD TX 79045-0871           0117     DEAF SMITH   79045
# 597795      MARBLE FALLS TX 78654-7385           0053         BURNET   78654
# 597796           PHOENIX AZ 85034-2208           0999   OUT OF STATE   85034
# 597797           MIDLAND TX 79701-4417           0329        MIDLAND   79701
# 597798            ALPINE TX 79830-1049           0043       BREWSTER   79830
# 597799  DRIPPING SPRINGS TX 78620-2477           0209           HAYS   78620
# 597800             BOWIE TX 76230-5969           0337       MONTAGUE   76230
# 597801      VALLEY MILLS TX 76689-2963           0035         BOSQUE   76689
# 597802  DRIPPING SPRINGS TX 78620-4097           0209           HAYS   78620
# 597803            UTOPIA TX 78884-2602           0463         UVALDE   78884
# 597804             QUAIL TX 79251-4126           0087  COLLINGSWORTH   79251
# 597805        PLEASANTON TX 78064-1733           0013       ATASCOSA   78064
# 597806           PHOENIX AZ 85034-2208           0999   OUT OF STATE   85034
# 597807         GROESBECK TX 76642-2304           0293      LIMESTONE   76642
# 597808            ATHENS TX 75751-2236           0213      HENDERSON   75751
# 597809      VALLEY MILLS TX 76689-2963           0035         BOSQUE   76689
# 597810        SAN ANGELO TX 76901-9716           0451      TOM GREEN   76901
# 597811            ROWENA TX 76875-2608           0399        RUNNELS   76875
# 597812            YOAKUM TX 77995-6786           0285         LAVACA   77995
# 597813         LEVELLAND TX 79336-9124           0219        HOCKLEY   79336
# 597814       FLORESVILLE TX 78114-6076           0493         WILSON   78114
#
#          TELEPHONE LICSUBTYPE CEFLAG    last_name
# 0       9039187899        NaN      N     WILLIAMS
# 1              NaN        NaN      N      GUEVARA
# 2       7136445566        NaN      N       BOWERS
# 3       2549852228        NaN      N       DEMSKY
# 4       5802765961        NaN      N     THOMPSON
# 5       5802250269        NaN      N       TUCKER
# 6       2815078713        NaN      N       COOPER
# 7       5802765961        NaN      N  BLANKENSHIP
# 8       2144091137        NaN      N        DAWES
# 9       9037825759        NaN      N       LESTER
# 10      9366749636        NaN      N      MANCILL
# 11      2106815425        NaN      N   HUDDLESTON
# 12      4322722266        NaN      N       JORDAN
# 13      4695951384        NaN      N        IRWIN
# 14      3253565950        NaN      N         HALL
# 15      2545928394        NaN      N        JAMES
# 16      8173200833        NaN      N       SIDAWI
# 17      3259386750        NaN      N        SMITH
# 18      3253727333        NaN      N     FERGUSON
# 19      9038453830        NaN      N     MCKINLEY
# 20      8173821530        NaN      N       SOWELL
# 21      9726930572        NaN      N       SEVIER
# 22      2542893216        NaN      N   SOMERVILLE
# 23      3253727333        NaN      N     BARCLIFT
# 24      2814797848        NaN      N         FORD
# 25      8062446776        NaN      N      SCHAFER
# 26      9153733887        NaN      N     MARTINEZ
# 27      8066833130        NaN      N      CLEMANS
# 28      9153733887        NaN      N     MARTINEZ
# 29      9035325501        NaN      N       CARSON
# ...            ...        ...    ...          ...
# 597785  9368566374          W      N      SNUFFER
# 597786  2106977114          M      N     MARTINEZ
# 597787  8063646140         KP      N       YOSTEN
# 597788  4326820703          W      N        CLICK
# 597789  9183223095          W      N        PENSE
# 597790  6024533252          M      N         LARA
# 597791  8068265975       KLPT      N        SMITH
# 597792  9363485838         PW      N    BINNICKER
# 597793  8178770866          M      N       CHAVEZ
# 597794  8063643109       KLPT      N     GUERRERO
# 597795  8306932340          P      N       SAVAGE
# 597796  6024533252          M      N        ADAMS
# 597797  4325578821          W      N        SCOTT
# 597798  4322942335        KLP      N         HILL
# 597799  5128944221         KP      N     THOMPSON
# 597800  9408726992          W      N       THOMAS
# 597801  2549326251        KPT      N    JURGENSEN
# 597802  5128584375          P      N        MARSH
# 597803  8309663456         KP      N     KILLOUGH
# 597804  8068981609      KLPTW      N       FAULKS
# 597805  8302812400        KPT      N       ATKINS
# 597806  6024533252          M      N     WILLIAMS
# 597807  2547293762          W      N     WINSTEAD
# 597808  9036752353        KLP      N       LILLEY
# 597809  2549326251          P      N        WOODS
# 597810  3259496607         KP      N         ABEL
# 597811  3254422331       KLPW      N         GRAY
# 597812  3612933168          P      N        MAYER
# 597813  8065980508          W      N      FRIESEN
# 597814  8303917338          W      N        BAUER
#
# [597815 rows x 20 columns]

# %% [markdown]
# # 15. What are the ten most popular last names?

# %%
df['last_name'].value_counts()
# Out:
# NGUYEN                         22355
# TRAN                            8167
# GARCIA                          5688
# LE                              5613
# MARTINEZ                        4809
# RODRIGUEZ                       4722
# HERNANDEZ                       4469
# PHAM                            4007
# GONZALEZ                        3693
# SMITH                           3351
# LOPEZ                           3052
# PEREZ                           2641
# WILLIAMS                        2550
# JOHNSON                         2504
# RAMIREZ                         2491
# HUYNH                           2441
# SANCHEZ                         2436
# FLORES                          2221
# GARZA                           2208
# JONES                           2187
# VO                              2013
# BROWN                           1975
# PHAN                            1792
# TORRES                          1777
# DAVIS                           1739
# VU                              1579
# TRUONG                          1489
# GOMEZ                           1446
# REYES                           1364
# DANG                            1362
#                                ...
# MELER                              1
# LOECHEL                            1
# SALON ARMIJO                       1
# OBID                               1
# SMARTWATT INC                      1
# DIVINE BEAUTY SALON                1
# ESTHETIC BEAUTY                    1
# TC TAYLOR LLC DBA FACELOGIC        1
# A & R PAYROLL SERVICES INC         1
# ACQUAYE                            1
# WANJOHI                            1
# AMAYA RECINOS                      1
# ENGLE-BRAZZIL                      1
# BAGBY'S BARBER SHOP                1
# PRIME SOURCE PAYROLL LP            1
# VP NAIL BAR                        1
# KOLBABA                            1
# KRHOVJAK                           1
# RITA'S CUTS AND WAVES              1
# CATE'S TOUCH                       1
# TEXSUN ELECTRIC                    1
# JIMENEZ MEJIA                      1
# OCEANS SPA ON BROADWAY             1
# PANZARDI                           1
# SHAHSWAR                           1
# PIRATE ISLAND POOLS LLC            1
# FRIEDERMAN                         1
# RCI ELECTRICAL SERVICES            1
# DAVIS-ORR                          1
# MCGILL ELECTRIC                    1
# Name: last_name, Length: 128435, dtype: int64

# %% [markdown]
# ## 16. What are the most popular licenses for people with the last name Nguyen? Tran? Le?
#
# Those are the top 3 last names in Vietnam.

# %%
nguyen = df[df['last_name'] == 'NGUYEN']

nguyen['LICTYPE'].value_counts(normalize=True).head()
# Out:
# Cosmetology Manicurist     0.575625
# Cosmetology Operator       0.180845
# Cosmetology Esthetician    0.128996
# Cosmetologist              0.083997
# Apprentice Electrician     0.008731
# Name: LICTYPE, dtype: float64

# %%
tran = df[df['last_name'] == 'TRAN']

tran['LICTYPE'].value_counts(normalize=True).head()
# Out:
# Cosmetology Manicurist     0.572846
# Cosmetology Operator       0.180738
# Cosmetology Esthetician    0.126455
# Cosmetologist              0.087244
# Apprentice Electrician     0.011641
# Name: LICTYPE, dtype: float64

# %%
lee = df[df['last_name'] == 'LEE']

lee['LICTYPE'].value_counts(normalize=True).head()
# Out:
# Cosmetology Operator      0.348110
# Apprentice Electrician    0.143416
# Cosmetology Manicurist    0.063885
# Journeyman Electrician    0.061278
# Barber, Class A           0.058670
# Name: LICTYPE, dtype: float64

# %% [markdown]
# ## 17. Now do all of that in one line - most popular licenses for Nguyen, Tran and Le - without using `&`

# %%
NTL = df [df['last_name'] == 'NGUYEN' | 'TRAN' | 'LEE']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-fd8823a324e6> in <module>
# ----> 1 NTL = df [df['last_name'] == 'NGUYEN' | 'TRAN' | 'LEE']
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %% [markdown]
# ## 18. Most popular licenses for Garcia? Rodriguez? Martinez?
#
# Those are the 3 most common last names for self-identifying Hispanics in the USA.

# %%
GR = df [df['last_name'] == 'GARCIA' | 'RODRIGUEZ']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-7a7a692f39a2> in <module>
# ----> 1 GR = df [df['last_name'] == 'GARCIA' | 'RODRIGUEZ']
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %%
df.last_name
# Out:
# 0            WILLIAMS
# 1             GUEVARA
# 2              BOWERS
# 3              DEMSKY
# 4            THOMPSON
# 5              TUCKER
# 6              COOPER
# 7         BLANKENSHIP
# 8               DAWES
# 9              LESTER
# 10            MANCILL
# 11         HUDDLESTON
# 12             JORDAN
# 13              IRWIN
# 14               HALL
# 15              JAMES
# 16             SIDAWI
# 17              SMITH
# 18           FERGUSON
# 19           MCKINLEY
# 20             SOWELL
# 21             SEVIER
# 22         SOMERVILLE
# 23           BARCLIFT
# 24               FORD
# 25            SCHAFER
# 26           MARTINEZ
# 27            CLEMANS
# 28           MARTINEZ
# 29             CARSON
#              ...
# 597785        SNUFFER
# 597786       MARTINEZ
# 597787         YOSTEN
# 597788          CLICK
# 597789          PENSE
# 597790           LARA
# 597791          SMITH
# 597792      BINNICKER
# 597793         CHAVEZ
# 597794       GUERRERO
# 597795         SAVAGE
# 597796          ADAMS
# 597797          SCOTT
# 597798           HILL
# 597799       THOMPSON
# 597800         THOMAS
# 597801      JURGENSEN
# 597802          MARSH
# 597803       KILLOUGH
# 597804         FAULKS
# 597805         ATKINS
# 597806       WILLIAMS
# 597807       WINSTEAD
# 597808         LILLEY
# 597809          WOODS
# 597810           ABEL
# 597811           GRAY
# 597812          MAYER
# 597813        FRIESEN
# 597814          BAUER
# Name: last_name, Length: 597815, dtype: object

# %% [markdown]
# ## 19. Most popular license for anyone with a last name that ENDS in `-ez`
#
# The answer is not `.str.contains('ez')`, but it isn't necessarily too different. **Make sure your numbers match mine.**
#
# One way involves a `.str.` method that check if a string ends with something, the other way involves a regular expression that has a "end of the string" marker (similar to how we've used `^` for the start of a string before). If you're thinking about the latter, I might take a look at [this page](http://www.rexegg.com/regex-quickstart.html) under "Anchors and Boundaries".

# %%
EZ = df[df['last_name'].str.contains('.*?EZ$', na =False)]

EZ['LICTYPE'].value_counts().head(1)
# Out:
# Apprentice Electrician    16065
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 20. Get that as a percentage

# %%
EZ['LICTYPE'].value_counts(normalize=True).head(1)
# Out:
# Apprentice Electrician    0.353341
# Name: LICTYPE, dtype: float64

# %% [markdown]
# # PART FOUR: LOOKING AT FIRST NAMES

# %% [markdown]
# ## 21. Extract the owner's first name
#
# First, a little example of how regular expressions work with pandas.

# %%
# Build a dataframe
sample_df = pd.DataFrame([
    { 'name': 'Mary', 'sentence': "I am 90 years old" },
    { 'name': 'Jack', 'sentence': "I am 4 years old" },
    { 'name': 'Anne', 'sentence': "I am 27 years old" },
    { 'name': 'Joel', 'sentence': "I am 13 years old" },
])
# Look at the dataframe
sample_df
# Out:
#    name           sentence
# 0  Mary  I am 90 years old
# 1  Jack   I am 4 years old
# 2  Anne  I am 27 years old
# 3  Joel  I am 13 years old

# %%
# Given the sentence, "I am X years old", extract digits from the middle using ()
# Anything you put in () will be saved as an output.
# If you do expand=True it makes you a dataframe, but we don't want that.
sample_df['sentence'].str.extract("I am (\d+) years old", expand=False)
# Out:
# 0    90
# 1     4
# 2    27
# 3    13
# Name: sentence, dtype: object

# %%
# Save it into a new column
sample_df['age'] = sample_df['sentence'].str.extract("I am (\d+) years old", expand=False)
sample_df.head()
# Out:
#    name           sentence age
# 0  Mary  I am 90 years old  90
# 1  Jack   I am 4 years old   4
# 2  Anne  I am 27 years old  27
# 3  Joel  I am 13 years old  13

# %% [markdown]
# **Now let's think about how we're going to extract the first names.** Begin by looking at a few full names.

# %%
df['OWNER'].head(10)
# Out:
# 0         WILLIAMS, JON ANDRE
# 1       GUEVARA, JUAN ANTONIO
# 2    BOWERS, JAMES BRISCOE II
# 3         DEMSKY, JOHN EDWARD
# 4           THOMPSON, RANDY D
# 5          TUCKER, MONTE EARL
# 6        COOPER, THOMAS JAMES
# 7     BLANKENSHIP, KERRY NEIL
# 8      DAWES, NICHOLAS MORGAN
# 9        LESTER, TIMMY EUGENE
# Name: OWNER, dtype: object

# %% [markdown]
# What can you use to find the first name? It helps to say "this is to the left and this is to the right, and I'm going to take anything in the middle."
#
# Once you figure out how to extract it, you can do a `.head(10)` to just look at the first few.

# %%
df['OWNER'].str.extract("J", expand=False)

# %% [markdown]
# ## 22. Saving the owner's first name
#
# Save the name to a new column, `FIRSTNAME`.

# %%
df['FIRSTNAME'] = df['OWNER'].str.extract(",[\s\S]*$", expand=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-2f38e29926f9> in <module>
# ----> 1 df['FIRSTNAME'] = df['OWNER'].str.extract(",[\s\S]*$", expand=False)
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\strings.py in extract(self, pat, flags, expand)
#    2765     @copy(str_extract)
#    2766     def extract(self, pat, flags=0, expand=True):
# -> 2767         return str_extract(self, pat, flags=flags, expand=expand)
#    2768
#    2769     @copy(str_extractall)
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\strings.py in str_extract(arr, pat, flags, expand)
#     848         return _str_extract_frame(arr._orig, pat, flags=flags)
#     849     else:
# --> 850         result, name = _str_extract_noexpand(arr._parent, pat, flags=flags)
#     851         return arr._wrap_result(result, name=name, expand=expand)
#     852
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\strings.py in _str_extract_noexpand(arr, pat, flags)
#     711
#     712     regex = re.compile(pat, flags=flags)
# --> 713     groups_or_na = _groups_or_na_fun(regex)
#     714
#     715     if regex.groups == 1:
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\strings.py in _groups_or_na_fun(regex)
#     686     """Used in both extract_noexpand and extract_frame"""
#     687     if regex.groups == 0:
# --> 688         raise ValueError("pattern contains no capture groups")
#     689     empty_row = [np.nan] * regex.groups
#     690
#
# ValueError: pattern contains no capture groups

# %% [markdown]
# # 23. Examine everyone without a first name
#
# I purposefully didn't do a nicer regex in order to have some screwed-up results. **How many people are there without an entry in the first name column?**
#
# Your numbers might be different than mine.

# %%
df['FIRSTNAME'].isnull().value_counts()
# Out:
# False    516214
# True      81601
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# What do their names look like?

# %%
df[df['FIRSTNAME'].isnull()]
# Out:
#                                   LICTYPE LICNUMBER   BIZCOUNTY  \
# 28021   Appliance Installation Contractor       101      HARRIS
# 28022   Appliance Installation Contractor       103      DALLAS
# 28023   Appliance Installation Contractor       104      DALLAS
# 28024   Appliance Installation Contractor       107       BOWIE
# 28025   Appliance Installation Contractor       108   FREESTONE
# 28026   Appliance Installation Contractor       109       BEXAR
# 28027   Appliance Installation Contractor       112      TRAVIS
# 28029   Appliance Installation Contractor       115      COLLIN
# 28030   Appliance Installation Contractor       116      HARRIS
# 28031   Appliance Installation Contractor       118      DALLAS
# 28032   Appliance Installation Contractor       120    COLORADO
# 28033   Appliance Installation Contractor       122        WOOD
# 28034   Appliance Installation Contractor       123       BOWIE
# 28035   Appliance Installation Contractor       125      DALLAS
# 28036   Appliance Installation Contractor       128  MONTGOMERY
# 28037   Appliance Installation Contractor       129  PALO PINTO
# 28038   Appliance Installation Contractor       131   GALVESTON
# 28039   Appliance Installation Contractor       132   TOM GREEN
# 28040   Appliance Installation Contractor       134    FRANKLIN
# 28041   Appliance Installation Contractor       135    ROCKWALL
# 28042   Appliance Installation Contractor       142     EL PASO
# 28043   Appliance Installation Contractor       143     RANDALL
# 28044   Appliance Installation Contractor       149       SMITH
# 28045   Appliance Installation Contractor       150     LUBBOCK
# 28046   Appliance Installation Contractor       153      HARRIS
# 28047   Appliance Installation Contractor       155  MONTGOMERY
# 28048   Appliance Installation Contractor       156        BELL
# 28049   Appliance Installation Contractor       160        WISE
# 28050   Appliance Installation Contractor       161      TRAVIS
# 28051   Appliance Installation Contractor       162     TARRANT
# ...                                   ...       ...         ...
# 590356           Used Auto Parts Recycler      1486      DALLAS
# 590357           Used Auto Parts Recycler      1487     EL PASO
# 590358           Used Auto Parts Recycler      1488      DALLAS
# 590359           Used Auto Parts Recycler      1489      HARRIS
# 590361           Used Auto Parts Recycler      1490        WEBB
# 590363           Used Auto Parts Recycler      1491     CORYELL
# 590364           Used Auto Parts Recycler      1492      HARRIS
# 590366           Used Auto Parts Recycler      1493     KAUFMAN
# 590367           Used Auto Parts Recycler      1494        WEBB
# 590369           Used Auto Parts Recycler      1495     TARRANT
# 590371           Used Auto Parts Recycler      1497       BEXAR
# 590373           Used Auto Parts Recycler      1498   FORT BEND
# 590375           Used Auto Parts Recycler      1499      DALLAS
# 590377           Used Auto Parts Recycler      1500        CLAY
# 590379           Used Auto Parts Recycler      1501     HIDALGO
# 590380           Used Auto Parts Recycler      1502        WEBB
# 590382           Used Auto Parts Recycler      1503     HIDALGO
# 590383           Used Auto Parts Recycler      1504      PARKER
# 590384           Used Auto Parts Recycler      1505      HARRIS
# 590386           Used Auto Parts Recycler      1506       ECTOR
# 590387           Used Auto Parts Recycler      1507        WEBB
# 590388           Used Auto Parts Recycler      1508     CAMERON
# 590389           Used Auto Parts Recycler      1509     CAMERON
# 590390           Used Auto Parts Recycler      1510     HIDALGO
# 590391           Used Auto Parts Recycler      1511        BELL
# 590394           Used Auto Parts Recycler      1513       BEXAR
# 590396           Used Auto Parts Recycler      1514      DALLAS
# 590398           Used Auto Parts Recycler      1515      HARRIS
# 590399           Used Auto Parts Recycler      1516      DALLAS
# 590400           Used Auto Parts Recycler      1517     TARRANT
#
#                                          BIZNAME BIZLINE1 BIZLINE2  \
# 28021    APPLIANCE INSTALLATION BY SPECIAL D LLC      NaN      NaN
# 28022                   CAPITAL DISTRIBUTING INC      NaN      NaN
# 28023                              INSTALLCO LLC      NaN      NaN
# 28024               LAFFERTYS TV & APPLIANCE INC      NaN      NaN
# 28025                            BALLARD COMPANY      NaN      NaN
# 28026                 FACTORY BUILDER STORES LTD      NaN      NaN
# 28027                          HARWAY SUPPLY INC      NaN      NaN
# 28029                           RODENBAUGH'S INC      NaN      NaN
# 28030                          RWB INSTALLATIONS      NaN      NaN
# 28031             D V S - DRYER VENTING SERVICES      NaN      NaN
# 28032             COLUMBUS TELEVISION CENTER INC      NaN      NaN
# 28033                        KIMMEN INSTALLATION      NaN      NaN
# 28034                       SEARS ROEBUCK AND CO      NaN      NaN
# 28035           INTRASTATE SALES ENTERPRISES INC      NaN      NaN
# 28036               MR HANDYMAN OF THE WOODLANDS      NaN      NaN
# 28037   DOSHIER APPL INC DBA DOSHIER APPL REPAIR      NaN      NaN
# 28038                         KELM HOME SERVICES      NaN      NaN
# 28039              TOM'S APPLIANCE INSTALLATIONS      NaN      NaN
# 28040                                 MJ FEAGLEY      NaN      NaN
# 28041                         SIMPLE RESOLUTIONS      NaN      NaN
# 28042                     SOBELLAS APPLIANCE LLC      NaN      NaN
# 28043           J & S INDUSTRIAL & MECHANICAL LP      NaN      NaN
# 28044               EAST TEXAS APPLIANCE SERVICE      NaN      NaN
# 28045                   CAPROCK APPLIANCE REPAIR      NaN      NaN
# 28046    KIVA KITCHEN/BATH MCNAIRS APPLIANCE INC      NaN      NaN
# 28047        TOMMY'S APPLIANCE INSTALLATIONS LLC      NaN      NaN
# 28048   TOLLY'S AIR CONDITIONING & REFRIGERATION      NaN      NaN
# 28049            COPLEN PLUMBING & INSTALLATIONS      NaN      NaN
# 28050                 DARYL FLOOD LOGISTICS INC.      NaN      NaN
# 28051                              SOLTHERMA INC      NaN      NaN
# ...                                          ...      ...      ...
# 590356             LKQ AUTO PARTS OF NORTH TEXAS      NaN      NaN
# 590357                          ANDRES AUTO SALE      NaN      NaN
# 590358             YOURFORD/TEXAS AUTO RECYCLERS      NaN      NaN
# 590359                      B & B RECYCLE CENTER      NaN      NaN
# 590361                    CAVAZOS AUTO SALES INC      NaN      NaN
# 590363                     D & R PICK N PULL LLC      NaN      NaN
# 590364                     DIXIE USED AUTO PARTS      NaN      NaN
# 590366             B&L TRUCK AND EQUIPMENT SALES      NaN      NaN
# 590367                       YONKE MONTERREY LLC      NaN      NaN
# 590369                       KTS INVESTMENTS LLC      NaN      NaN
# 590371             PRIMARY OPPURTUNITY GROUP LLC      NaN      NaN
# 590373                    ALPINE USED AUTO PARTS      NaN      NaN
# 590375                  AAA AUTO SALVAGE & PARTS      NaN      NaN
# 590377                   HENRIETTA AUTO SHOP LLC      NaN      NaN
# 590379                        YESENIA A HINOJOSA      NaN      NaN
# 590380                             BMW PARTS INC      NaN      NaN
# 590382                MARIA I COELLO DE MARTINEZ      NaN      NaN
# 590383                    REV ACTION TRUCK PARTS      NaN      NaN
# 590384                     WHITTS AUTO SALES LLC      NaN      NaN
# 590386                   MARTINEZ AUTOMOTIVE INC      NaN      NaN
# 590387                   PAISANO USED AUTO PARTS      NaN      NaN
# 590388                         ANSELDA NIQUELINA      NaN      NaN
# 590389                            JUAN A.DE LEON      NaN      NaN
# 590390                          J & MS PARTS LLC      NaN      NaN
# 590391                                  SNYDER'S      NaN      NaN
# 590394                          R & D PARTS INC.      NaN      NaN
# 590396                    DFW AUTO & PARTS SALES      NaN      NaN
# 590398              T&D BRADLEY AUTO SERVICE LLC      NaN      NaN
# 590399                          A & M AUTO PARTS      NaN      NaN
# 590400                   STEVENS CORE SUPPLY INC      NaN      NaN
#
#        BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 28021           NaN          NaN   05232017
# 28022           NaN          NaN   04082017
# 28023           NaN          NaN   04082017
# 28024           NaN          NaN   03202018
# 28025           NaN          NaN   04022017
# 28026           NaN          NaN   02072018
# 28027           NaN          NaN   04112018
# 28029           NaN          NaN   04112017
# 28030           NaN          NaN   04152018
# 28031           NaN          NaN   04162018
# 28032           NaN          NaN   04172018
# 28033           NaN          NaN   12212017
# 28034           NaN          NaN   04182018
# 28035           NaN          NaN   04282016
# 28036           NaN          NaN   05172017
# 28037           NaN          NaN   10262017
# 28038           NaN          NaN   07162016
# 28039           NaN          NaN   05242017
# 28040           NaN          NaN   05272017
# 28041           NaN          NaN   01282018
# 28042           NaN          NaN   07292017
# 28043           NaN          NaN   08012017
# 28044           NaN          NaN   11142017
# 28045           NaN          NaN   11142017
# 28046           NaN          NaN   03252017
# 28047           NaN          NaN   03172017
# 28048           NaN          NaN   03022018
# 28049           NaN          NaN   09182017
# 28050           NaN          NaN   05112017
# 28051           NaN          NaN   07082017
# ...             ...          ...        ...
# 590356          NaN          NaN   11022017
# 590357          NaN          NaN   11022017
# 590358          NaN          NaN   11082017
# 590359          NaN          NaN   11142017
# 590361          NaN          NaN   11152017
# 590363          NaN          NaN   11182017
# 590364          NaN          NaN   11222017
# 590366          NaN          NaN   11282017
# 590367          NaN          NaN   11302017
# 590369          NaN          NaN   12052017
# 590371          NaN          NaN   12152017
# 590373          NaN          NaN   12162017
# 590375          NaN          NaN   12202017
# 590377          NaN          NaN   12202017
# 590379          NaN          NaN   12212017
# 590380          NaN          NaN   12222017
# 590382          NaN          NaN   12222017
# 590383          NaN          NaN   12272017
# 590384          NaN          NaN   01042018
# 590386          NaN          NaN   01092018
# 590387          NaN          NaN   01132018
# 590388          NaN          NaN   01182018
# 590389          NaN          NaN   01252018
# 590390          NaN          NaN   02072018
# 590391          NaN          NaN   02072018
# 590394          NaN          NaN   02162018
# 590396          NaN          NaN   02242018
# 590398          NaN          NaN   02242018
# 590399          NaN          NaN   02282018
# 590400          NaN          NaN   03012018
#
#                                            OWNER  ...  \
# 28021    APPLIANCE INSTALLATION BY SPECIAL D LLC  ...
# 28022                   CAPITAL DISTRIBUTING INC  ...
# 28023                              INSTALLCO LLC  ...
# 28024               LAFFERTYS TV & APPLIANCE INC  ...
# 28025                            BALLARD COMPANY  ...
# 28026                 FACTORY BUILDER STORES LTD  ...
# 28027                          HARWAY SUPPLY INC  ...
# 28029                           RODENBAUGH'S INC  ...
# 28030                          RWB INSTALLATIONS  ...
# 28031             D V S - DRYER VENTING SERVICES  ...
# 28032             COLUMBUS TELEVISION CENTER INC  ...
# 28033                        KIMMEN INSTALLATION  ...
# 28034                       SEARS ROEBUCK AND CO  ...
# 28035           INTRASTATE SALES ENTERPRISES INC  ...
# 28036               MR HANDYMAN OF THE WOODLANDS  ...
# 28037   DOSHIER APPL INC DBA DOSHIER APPL REPAIR  ...
# 28038                         KELM HOME SERVICES  ...
# 28039              TOM'S APPLIANCE INSTALLATIONS  ...
# 28040                                 MJ FEAGLEY  ...
# 28041                         SIMPLE RESOLUTIONS  ...
# 28042                     SOBELLAS APPLIANCE LLC  ...
# 28043           J & S INDUSTRIAL & MECHANICAL LP  ...
# 28044               EAST TEXAS APPLIANCE SERVICE  ...
# 28045                   CAPROCK APPLIANCE REPAIR  ...
# 28046    KIVA KITCHEN/BATH MCNAIRS APPLIANCE INC  ...
# 28047        TOMMY'S APPLIANCE INSTALLATIONS LLC  ...
# 28048   TOLLY'S AIR CONDITIONING & REFRIGERATION  ...
# 28049            COPLEN PLUMBING & INSTALLATIONS  ...
# 28050                 DARYL FLOOD LOGISTICS INC.  ...
# 28051                              SOLTHERMA INC  ...
# ...                                          ...  ...
# 590356             LKQ AUTO PARTS OF NORTH TEXAS  ...
# 590357                          ANDRES AUTO SALE  ...
# 590358             YOURFORD/TEXAS AUTO RECYCLERS  ...
# 590359                      B & B RECYCLE CENTER  ...
# 590361                    CAVAZOS AUTO SALES INC  ...
# 590363                     D & R PICK N PULL LLC  ...
# 590364                     DIXIE USED AUTO PARTS  ...
# 590366             B&L TRUCK AND EQUIPMENT SALES  ...
# 590367                       YONKE MONTERREY LLC  ...
# 590369                       KTS INVESTMENTS LLC  ...
# 590371             PRIMARY OPPURTUNITY GROUP LLC  ...
# 590373                    ALPINE USED AUTO PARTS  ...
# 590375                  AAA AUTO SALVAGE & PARTS  ...
# 590377                   HENRIETTA AUTO SHOP LLC  ...
# 590379                        YESENIA A HINOJOSA  ...
# 590380                             BMW PARTS INC  ...
# 590382                MARIA I COELLO DE MARTINEZ  ...
# 590383                    REV ACTION TRUCK PARTS  ...
# 590384                     WHITTS AUTO SALES LLC  ...
# 590386                   MARTINEZ AUTOMOTIVE INC  ...
# 590387                   PAISANO USED AUTO PARTS  ...
# 590388                         ANSELDA NIQUELINA  ...
# 590389                            JUAN A.DE LEON  ...
# 590390                          J & MS PARTS LLC  ...
# 590391                                  SNYDER'S  ...
# 590394                          R & D PARTS INC.  ...
# 590396                    DFW AUTO & PARTS SALES  ...
# 590398              T&D BRADLEY AUTO SERVICE LLC  ...
# 590399                          A & M AUTO PARTS  ...
# 590400                   STEVENS CORE SUPPLY INC  ...
#
#                       MAILCITYSTATE MAILCOUNTYCODE    MAILCOUNTY MAILZIP  \
# 28021              HOUSTON TX 77093           0201        HARRIS   77093
# 28022          DALLAS TX 75247-6103           0113        DALLAS   75247
# 28023          DALLAS TX 75247-6103           0113        DALLAS   75247
# 28024            TEXARKANA TX 75503           0037         BOWIE   75503
# 28025            FAIRFIELD TX 75840           0161     FREESTONE   75840
# 28026          SAN ANTONIO TX 78247           0029         BEXAR   78247
# 28027               AUSTIN TX 78758           0453        TRAVIS   78758
# 28029           ALLEN TX 75013-2764           0085        COLLIN   75013
# 28030             LA PORTE TX 77571           0201        HARRIS   77571
# 28031                PLANO TX 75023           0085        COLLIN   75023
# 28032        COLUMBUS TX 78934-2216           0089      COLORADO   78934
# 28033            WINNSBORO TX 75494           0499          WOOD   75494
# 28034      HOFFMAN ESTATES IL 60179           0999  OUT OF STATE   60179
# 28035          DALLAS TX 75229-4730           0113        DALLAS   75229
# 28036               SPRING TX 77382           0339    MONTGOMERY   77382
# 28037        MINERAL WELLS TX 76067           0363    PALO PINTO   76067
# 28038             SANTA FE TX 77517           0167     GALVESTON   77517
# 28039      SAN ANGELO TX 76904-6001           0451     TOM GREEN   76904
# 28040            SCROGGINS TX 75480           0159      FRANKLIN   75480
# 28041           ROYSE CITY TX 75189           0397      ROCKWALL   75189
# 28042              EL PASO TX 79932           0141       EL PASO   79932
# 28043             AMARILLO TX 79118           0381       RANDALL   79118
# 28044           TYLER TX 75703-5301           0423         SMITH   75703
# 28045              LUBBOCK TX 79410           0303       LUBBOCK   79410
# 28046          AUSTIN TX 78758-7659           0453        TRAVIS   78758
# 28047               CONROE TX 77302           0339    MONTGOMERY   77302
# 28048              KILLEEN TX 76549           0027          BELL   76549
# 28049            BOYD TX 76023-0181           0497          WISE   76023
# 28050          AUSTIN TX 78728-3953           0453        TRAVIS   78728
# 28051               HASLET TX 76052           0439       TARRANT   76052
# ...                             ...            ...           ...     ...
# 590356  NEW BRAUNFELS TX 78130-3590           0091         COMAL   78130
# 590357        EL PASO TX 79938-7205           0141       EL PASO   79938
# 590358       GRAND PRAIRIE TX 75051           0113        DALLAS   75051
# 590359        HOUSTON TX 77074-1300           0201        HARRIS   77074
# 590361         LAREDO TX 78040-3749           0479          WEBB   78040
# 590363  COPPERAS COVE TX 76522-3859           0099       CORYELL   76522
# 590364           NEW CANEY TX 77357           0339    MONTGOMERY   77357
# 590366                KEMP TX 75143           0257       KAUFMAN   75143
# 590367              LAREDO TX 78043           0479          WEBB   78043
# 590369          FORT WORTH TX 76117           0439       TARRANT   76117
# 590371    SAN ANTONIO TX 78211-1920           0029         BEXAR   78211
# 590373            STAFFORD TX 77477           0157     FORT BEND   77477
# 590375        HUBBARD TX 76648-2451           0217          HILL   76648
# 590377      HENRIETTA TX 76365-3235           0077          CLAY   76365
# 590379             MCALLEN TX 78503           0215       HIDALGO   78503
# 590380         LAREDO TX 78043-4899           0479          WEBB   78043
# 590382        HIDALGO TX 78557-3873           0215       HIDALGO   78557
# 590383     SPRINGTOWN TX 76082-6915           0367        PARKER   76082
# 590384        HOUSTON TX 77077-3301           0201        HARRIS   77077
# 590386         ODESSA TX 79764-9005           0135         ECTOR   79764
# 590387              LAREDO TX 78043           0479          WEBB   78043
# 590388      HARLINGEN TX 78552-6797           0061       CAMERON   78552
# 590389         OLMITO TX 78575-5216           0061       CAMERON   78575
# 590390             MCALLEN TX 78503           0215       HIDALGO   78503
# 590391         SAN ANTONIO TX 78219           0029         BEXAR   78219
# 590394         SAN ANTONIO TX 78211           0029         BEXAR   78211
# 590396         HALTOM CITY TX 76117           0439       TARRANT   76117
# 590398        HOUSTON TX 77022-6106           0201        HARRIS   77022
# 590399         DALLAS TX 75216-4138           0113        DALLAS   75216
# 590400         SANSOM PARK TX 76114           0439       TARRANT   76114
#
#          TELEPHONE LICSUBTYPE CEFLAG  \
# 28021   2815363711       RAIC      N
# 28022   2146382681       RAIC      N
# 28023   2142761033       RAIC      N
# 28024   9037942581       RAIC      N
# 28025   9033895774       RAIC      N
# 28026   2103499333       RAIC      N
# 28027   5124917600       RAIC      N
# 28029   9727273454       RAIC      N
# 28030   7134774700       RAIC      N
# 28031   2148020600       RAIC      N
# 28032   9797326054       RAIC      N
# 28033   9036130236       RAIC      N
# 28034   9037947327       RAIC      N
# 28035   2143576879       RAIC      N
# 28036   2812962700       RAIC      N
# 28037   9403255555       RAIC      N
# 28038   4093169834       RAIC      N
# 28039   3256563668       RAIC      N
# 28040   9038603176       RAIC      N
# 28041   2144503323       RAIC      N
# 28042   9155852811       RAIC      N
# 28043   8066220990       RAIC      N
# 28044   9035818200       RAIC      N
# 28045   8067840744       RAIC      N
# 28046   5124544526       RAIC      N
# 28047   9364463250       RAIC      N
# 28048   2545190714       RAIC      N
# 28049   8175599185       RAIC      N
# 28050   5126703777       RAIC      N
# 28051   8174272112       RAIC      N
# ...            ...        ...    ...
# 590356  8307433091   RECYCLER      N
# 590357  9153037448   RECYCLER      N
# 590358  9722633303   RECYCLER      N
# 590359  7139816272   RECYCLER      N
# 590361  9567274123   RECYCLER      N
# 590363  2542450526   RECYCLER      N
# 590364  2816893111   RECYCLER      N
# 590366  9723747036   RECYCLER      N
# 590367  9567299333   RECYCLER      N
# 590369  8178316316   RECYCLER      N
# 590371  2103991648   RECYCLER      N
# 590373  2812610606   RECYCLER      N
# 590375  4694412184   RECYCLER      N
# 590377  9405384621   RECYCLER      N
# 590379  9564510794   RECYCLER      N
# 590380  9567910977   RECYCLER      N
# 590382  9565331827   RECYCLER      N
# 590383  9407048687   RECYCLER      N
# 590384  2815890334   RECYCLER      N
# 590386  4323850076   RECYCLER      N
# 590387  9567448415   RECYCLER      N
# 590388  9564251335   RECYCLER      N
# 590389  9563508299   RECYCLER      N
# 590390  9568435171   RECYCLER      N
# 590391  2103266220   RECYCLER      N
# 590394  2106232000   RECYCLER      N
# 590396  8174399281   RECYCLER      N
# 590398  8322096210   RECYCLER      N
# 590399  2143711500   RECYCLER      N
# 590400  8173329820   RECYCLER      N
#
#                                        last_name first_name FIRSTNAME
# 28021    APPLIANCE INSTALLATION BY SPECIAL D LLC        NaN       NaN
# 28022                   CAPITAL DISTRIBUTING INC        NaN       NaN
# 28023                              INSTALLCO LLC        NaN       NaN
# 28024               LAFFERTYS TV & APPLIANCE INC        NaN       NaN
# 28025                            BALLARD COMPANY        NaN       NaN
# 28026                 FACTORY BUILDER STORES LTD        NaN       NaN
# 28027                          HARWAY SUPPLY INC        NaN       NaN
# 28029                           RODENBAUGH'S INC        NaN       NaN
# 28030                          RWB INSTALLATIONS        NaN       NaN
# 28031             D V S - DRYER VENTING SERVICES        NaN       NaN
# 28032             COLUMBUS TELEVISION CENTER INC        NaN       NaN
# 28033                        KIMMEN INSTALLATION        NaN       NaN
# 28034                       SEARS ROEBUCK AND CO        NaN       NaN
# 28035           INTRASTATE SALES ENTERPRISES INC        NaN       NaN
# 28036               MR HANDYMAN OF THE WOODLANDS        NaN       NaN
# 28037   DOSHIER APPL INC DBA DOSHIER APPL REPAIR        NaN       NaN
# 28038                         KELM HOME SERVICES        NaN       NaN
# 28039              TOM'S APPLIANCE INSTALLATIONS        NaN       NaN
# 28040                                 MJ FEAGLEY        NaN       NaN
# 28041                         SIMPLE RESOLUTIONS        NaN       NaN
# 28042                     SOBELLAS APPLIANCE LLC        NaN       NaN
# 28043           J & S INDUSTRIAL & MECHANICAL LP        NaN       NaN
# 28044               EAST TEXAS APPLIANCE SERVICE        NaN       NaN
# 28045                   CAPROCK APPLIANCE REPAIR        NaN       NaN
# 28046    KIVA KITCHEN/BATH MCNAIRS APPLIANCE INC        NaN       NaN
# 28047        TOMMY'S APPLIANCE INSTALLATIONS LLC        NaN       NaN
# 28048   TOLLY'S AIR CONDITIONING & REFRIGERATION        NaN       NaN
# 28049            COPLEN PLUMBING & INSTALLATIONS        NaN       NaN
# 28050                 DARYL FLOOD LOGISTICS INC.        NaN       NaN
# 28051                              SOLTHERMA INC        NaN       NaN
# ...                                          ...        ...       ...
# 590356             LKQ AUTO PARTS OF NORTH TEXAS        NaN       NaN
# 590357                          ANDRES AUTO SALE        NaN       NaN
# 590358             YOURFORD/TEXAS AUTO RECYCLERS        NaN       NaN
# 590359                      B & B RECYCLE CENTER        NaN       NaN
# 590361                    CAVAZOS AUTO SALES INC        NaN       NaN
# 590363                     D & R PICK N PULL LLC        NaN       NaN
# 590364                     DIXIE USED AUTO PARTS        NaN       NaN
# 590366             B&L TRUCK AND EQUIPMENT SALES        NaN       NaN
# 590367                       YONKE MONTERREY LLC        NaN       NaN
# 590369                       KTS INVESTMENTS LLC        NaN       NaN
# 590371             PRIMARY OPPURTUNITY GROUP LLC        NaN       NaN
# 590373                    ALPINE USED AUTO PARTS        NaN       NaN
# 590375                  AAA AUTO SALVAGE & PARTS        NaN       NaN
# 590377                   HENRIETTA AUTO SHOP LLC        NaN       NaN
# 590379                        YESENIA A HINOJOSA        NaN       NaN
# 590380                             BMW PARTS INC        NaN       NaN
# 590382                MARIA I COELLO DE MARTINEZ        NaN       NaN
# 590383                    REV ACTION TRUCK PARTS        NaN       NaN
# 590384                     WHITTS AUTO SALES LLC        NaN       NaN
# 590386                   MARTINEZ AUTOMOTIVE INC        NaN       NaN
# 590387                   PAISANO USED AUTO PARTS        NaN       NaN
# 590388                         ANSELDA NIQUELINA        NaN       NaN
# 590389                            JUAN A.DE LEON        NaN       NaN
# 590390                          J & MS PARTS LLC        NaN       NaN
# 590391                                  SNYDER'S        NaN       NaN
# 590394                          R & D PARTS INC.        NaN       NaN
# 590396                    DFW AUTO & PARTS SALES        NaN       NaN
# 590398              T&D BRADLEY AUTO SERVICE LLC        NaN       NaN
# 590399                          A & M AUTO PARTS        NaN       NaN
# 590400                   STEVENS CORE SUPPLY INC        NaN       NaN
#
# [81601 rows x 22 columns]

# %% [markdown]
# ## 24. If it's a problem, you can fix it (if you'd like!)
#
# Maybe you have another regular expression that works better with JUST these people? It really depends on how you've put together your previous regex!
#
# If you'd like to use a separate regex for this group, you can use code like this:
#
# `df.loc[df.FIRSTNAME.isnull(), 'FIRSTNAME'] = .....`
#
# That will only set the `FIRSTNAME` for people where `FIRSTNAME` is null.

# %%
FIRSTNAME = df.loc[df.FIRSTNAME.isnull(), 'FIRSTNAME']

# %% [markdown]
# How many empty first names do we have now?

# %%
FIRSTNAME.isnull().value_counts()
# Out:
# True    81601
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# My code before only worked for people with middle names, but now it got people without middle names, too. Looking much better!

# %% [markdown]
# ## 25. Most popular first names?

# %%
df.first_name.value_counts()
# Out:
# NGUYEN             22286
# TRAN                8137
# LE                  5606
# GARCIA              5574
# MARTINEZ            4701
# RODRIGUEZ           4626
# HERNANDEZ           4390
# PHAM                3997
# GONZALEZ            3634
# SMITH               3208
# LOPEZ               2992
# PEREZ               2583
# WILLIAMS            2468
# HUYNH               2436
# RAMIREZ             2433
# JOHNSON             2402
# SANCHEZ             2381
# FLORES              2164
# GARZA               2145
# JONES               2105
# VO                  2009
# BROWN               1908
# PHAN                1787
# TORRES              1749
# DAVIS               1671
# VU                  1575
# TRUONG              1487
# GOMEZ               1409
# DANG                1359
# HOANG               1349
#                    ...
# CRUZ CERDA             1
# NARR                   1
# JUBAILI                1
# OONWALA                1
# ROJAS-VAZQUEZ          1
# MOFA                   1
# AL KHATTAN             1
# AVILA-REYES            1
# ZIRION                 1
# WIIKI                  1
# BILLMIRE               1
# MECHAM                 1
# SKOCIBUSIC             1
# GARCIA-OLVERA          1
# CRAVY                  1
# KURESKA                1
# LOPEZ MATA             1
# CLEMMER                1
# MORENOVALLE            1
# ROVATSOS               1
# LOKHANDWALLA           1
# GONZALEZ LEIVA         1
# LATAPIE                1
# BAYBO                  1
# PATE                   1
# TELAS                  1
# PEREZ HERRERA          1
# VADE                   1
# HOI                    1
# VASQUEZ SUTUJ          1
# Name: first_name, Length: 73642, dtype: int64

# %% [markdown]
# ## 26. Most popular first names for a Cosmetology Operator, Cosmetology Esthetician, Cosmetologist, and okay honestly anything that seems similar?
#
# If you get an error about "cannot index vector containing NA / NaN values" remember `.fillna(False)` - if a row doesn't have a license, it doesn't give a `True`/`False`, so we force all of the empty rows to be `False`.

# %%
df.first_name = df.first_name.fillna(False)

# %%
df..str.contains('stringname', na=True/False)

# %% [markdown]
# ## 27. Most popular first names for anything involving electricity?

# %%
df
# Out:
#                                   LICTYPE LICNUMBER      BIZCOUNTY  \
# 0                    Associate Auctioneer      7962         UPSHUR
# 1                    Associate Auctioneer      8406         WILSON
# 2                    Associate Auctioneer     10543         HARRIS
# 3                    Associate Auctioneer     10642           BELL
# 4                    Associate Auctioneer     15650   OUT OF STATE
# 5                    Associate Auctioneer     15698   OUT OF STATE
# 6                    Associate Auctioneer     15810          MILAM
# 7                    Associate Auctioneer     15835   OUT OF STATE
# 8                    Associate Auctioneer     16784   OUT OF STATE
# 9                    Associate Auctioneer     16893          LAMAR
# 10                   Associate Auctioneer     16969    NACOGDOCHES
# 11                   Associate Auctioneer     16990          BEXAR
# 12                   Associate Auctioneer     17072          ECTOR
# 13                   Associate Auctioneer     17108        KAUFMAN
# 14                   Associate Auctioneer     17241           HOOD
# 15                   Associate Auctioneer     17242          ERATH
# 16                   Associate Auctioneer     17669        JOHNSON
# 17                   Associate Auctioneer     17671          MILLS
# 18                   Associate Auctioneer     17672          BROWN
# 19                   Associate Auctioneer     17675         UPSHUR
# 20                   Associate Auctioneer     17676        JOHNSON
# 21                   Associate Auctioneer     17679          ELLIS
# 22                   Associate Auctioneer     17680           BELL
# 23                   Associate Auctioneer     17685       SAN SABA
# 24                   Associate Auctioneer     17687         HARRIS
# 25                   Associate Auctioneer     17689         DALLAM
# 26                   Associate Auctioneer     17695        EL PASO
# 27                   Associate Auctioneer     17696         POTTER
# 28                   Associate Auctioneer     17699        EL PASO
# 29                   Associate Auctioneer     17706        GRAYSON
# ...                                   ...       ...            ...
# 597785  Water Well Driller/Pump Installer     59847     MONTGOMERY
# 597786  Water Well Driller/Pump Installer     59856          BEXAR
# 597787  Water Well Driller/Pump Installer     59857     DEAF SMITH
# 597788  Water Well Driller/Pump Installer     59858        MIDLAND
# 597789  Water Well Driller/Pump Installer     59862   OUT OF STATE
# 597790  Water Well Driller/Pump Installer     59877   OUT OF STATE
# 597791  Water Well Driller/Pump Installer     59878        WHEELER
# 597792  Water Well Driller/Pump Installer     59879        MADISON
# 597793  Water Well Driller/Pump Installer     59886        TARRANT
# 597794  Water Well Driller/Pump Installer     59887     DEAF SMITH
# 597795  Water Well Driller/Pump Installer     59889         BURNET
# 597796  Water Well Driller/Pump Installer     59890   OUT OF STATE
# 597797  Water Well Driller/Pump Installer     59892        MIDLAND
# 597798  Water Well Driller/Pump Installer     59896       BREWSTER
# 597799  Water Well Driller/Pump Installer     59901           HAYS
# 597800  Water Well Driller/Pump Installer     59902         DENTON
# 597801  Water Well Driller/Pump Installer     59904         BOSQUE
# 597802  Water Well Driller/Pump Installer     59905           HAYS
# 597803  Water Well Driller/Pump Installer     59907         UVALDE
# 597804  Water Well Driller/Pump Installer     59908  COLLINGSWORTH
# 597805  Water Well Driller/Pump Installer     59911       ATASCOSA
# 597806  Water Well Driller/Pump Installer     59912   OUT OF STATE
# 597807  Water Well Driller/Pump Installer     59913      LIMESTONE
# 597808  Water Well Driller/Pump Installer     59926      HENDERSON
# 597809  Water Well Driller/Pump Installer     59929         BOSQUE
# 597810  Water Well Driller/Pump Installer     59930      TOM GREEN
# 597811  Water Well Driller/Pump Installer     59931        RUNNELS
# 597812  Water Well Driller/Pump Installer     59934         LAVACA
# 597813  Water Well Driller/Pump Installer     59936        HOCKLEY
# 597814  Water Well Driller/Pump Installer     59941         WILSON
#
#                            BIZNAME BIZLINE1 BIZLINE2 BIZCITYSTATE  \
# 0              WILLIAMS, JON ANDRE      NaN      NaN          NaN
# 1            GUEVARA, JUAN ANTONIO      NaN      NaN          NaN
# 2         BOWERS, JAMES BRISCOE II      NaN      NaN          NaN
# 3              DEMSKY, JOHN EDWARD      NaN      NaN          NaN
# 4                THOMPSON, RANDY D      NaN      NaN          NaN
# 5               TUCKER, MONTE EARL      NaN      NaN          NaN
# 6             COOPER, THOMAS JAMES      NaN      NaN          NaN
# 7          BLANKENSHIP, KERRY NEIL      NaN      NaN          NaN
# 8           DAWES, NICHOLAS MORGAN      NaN      NaN          NaN
# 9             LESTER, TIMMY EUGENE      NaN      NaN          NaN
# 10             MANCILL, MARK DUANE      NaN      NaN          NaN
# 11          HUDDLESTON, SHAWN ALAN      NaN      NaN          NaN
# 12            JORDAN, JAMES EUGENE      NaN      NaN          NaN
# 13          IRWIN, MICHAEL RICHARD      NaN      NaN          NaN
# 14               HALL, WESLEY RYON      NaN      NaN          NaN
# 15              JAMES, BACHUS ROSS      NaN      NaN          NaN
# 16            SIDAWI, JOSEPH JAMES      NaN      NaN          NaN
# 17              SMITH, DAVID JAMES      NaN      NaN          NaN
# 18            FERGUSON, JACKIE LEE      NaN      NaN          NaN
# 19             MCKINLEY, MATTHEW D      NaN      NaN          NaN
# 20             SOWELL, KALEN BRICE      NaN      NaN          NaN
# 21              SEVIER, VIRGINIA A      NaN      NaN          NaN
# 22               SOMERVILLE, CAL W      NaN      NaN          NaN
# 23          BARCLIFT, AUSTIN TYLER      NaN      NaN          NaN
# 24             FORD, PATRICIA NORA      NaN      NaN          NaN
# 25           SCHAFER, TIMOTHY RYAN      NaN      NaN          NaN
# 26          MARTINEZ, BRANDY MARIE      NaN      NaN          NaN
# 27            CLEMANS, ZACHARY LEE      NaN      NaN          NaN
# 28                MARTINEZ, ARTURO      NaN      NaN          NaN
# 29              CARSON, DAVID WADE      NaN      NaN          NaN
# ...                            ...      ...      ...          ...
# 597785      SNUFFER, KENNETH DAVID      NaN      NaN          NaN
# 597786            MARTINEZ, JUAN R      NaN      NaN          NaN
# 597787        YOSTEN, BLAKE JOSEPH      NaN      NaN          NaN
# 597788           CLICK, JAY MARCUS      NaN      NaN          NaN
# 597789          PENSE, LARRY WAYNE      NaN      NaN          NaN
# 597790              LARA, STEVEN D      NaN      NaN          NaN
# 597791               SMITH, JACE E      NaN      NaN          NaN
# 597792    BINNICKER, RICHARD ALLEN      NaN      NaN          NaN
# 597793    CHAVEZ, FRANCISCO JAVIER      NaN      NaN          NaN
# 597794             GUERRERO, REY S      NaN      NaN          NaN
# 597795  SAVAGE, CROCKETT NATHANIEL      NaN      NaN          NaN
# 597796              ADAMS, AARON J      NaN      NaN          NaN
# 597797              SCOTT, JAMES A      NaN      NaN          NaN
# 597798             HILL, RYAN WADE      NaN      NaN          NaN
# 597799         THOMPSON, JARED W T      NaN      NaN          NaN
# 597800        THOMAS, WESLEY WAYNE      NaN      NaN          NaN
# 597801      JURGENSEN, JOSHUA MARK      NaN      NaN          NaN
# 597802         MARSH, AARON ANDREW      NaN      NaN          NaN
# 597803       KILLOUGH, BRUCE WAYNE      NaN      NaN          NaN
# 597804        FAULKS, CARSON SLADE      NaN      NaN          NaN
# 597805    ATKINS, BRANDON BUCHANAN      NaN      NaN          NaN
# 597806            WILLIAMS, MARC R      NaN      NaN          NaN
# 597807      WINSTEAD, CLINTON WADE      NaN      NaN          NaN
# 597808             LILLEY, CLINTON      NaN      NaN          NaN
# 597809              WOODS, JACOB R      NaN      NaN          NaN
# 597810              ABEL, JUSTIN C      NaN      NaN          NaN
# 597811         GRAY, MATTHEW BRYAN      NaN      NaN          NaN
# 597812              MAYER, DAVID W      NaN      NaN          NaN
# 597813     FRIESEN, FRANCISCO FEHR      NaN      NaN          NaN
# 597814              BAUER, DAVID A      NaN      NaN          NaN
#
#        BIZTELEPHONE EXPIRATION                       OWNER  ...  \
# 0               NaN   12292017         WILLIAMS, JON ANDRE  ...
# 1               NaN   09262017       GUEVARA, JUAN ANTONIO  ...
# 2               NaN   11042017    BOWERS, JAMES BRISCOE II  ...
# 3               NaN   02252018         DEMSKY, JOHN EDWARD  ...
# 4               NaN   05042017           THOMPSON, RANDY D  ...
# 5               NaN   06162017          TUCKER, MONTE EARL  ...
# 6               NaN   03182017        COOPER, THOMAS JAMES  ...
# 7               NaN   05042017     BLANKENSHIP, KERRY NEIL  ...
# 8               NaN   10192017      DAWES, NICHOLAS MORGAN  ...
# 9               NaN   08192017        LESTER, TIMMY EUGENE  ...
# 10              NaN   04212017         MANCILL, MARK DUANE  ...
# 11              NaN   02182017      HUDDLESTON, SHAWN ALAN  ...
# 12              NaN   02182018        JORDAN, JAMES EUGENE  ...
# 13              NaN   02252017      IRWIN, MICHAEL RICHARD  ...
# 14              NaN   01252018           HALL, WESLEY RYON  ...
# 15              NaN   05042017          JAMES, BACHUS ROSS  ...
# 16              NaN   02082017        SIDAWI, JOSEPH JAMES  ...
# 17              NaN   02082018          SMITH, DAVID JAMES  ...
# 18              NaN   02092018        FERGUSON, JACKIE LEE  ...
# 19              NaN   02182018         MCKINLEY, MATTHEW D  ...
# 20              NaN   02182018         SOWELL, KALEN BRICE  ...
# 21              NaN   02252018          SEVIER, VIRGINIA A  ...
# 22              NaN   02252017           SOMERVILLE, CAL W  ...
# 23              NaN   03172018      BARCLIFT, AUSTIN TYLER  ...
# 24              NaN   03182017         FORD, PATRICIA NORA  ...
# 25              NaN   04012017       SCHAFER, TIMOTHY RYAN  ...
# 26              NaN   04112017      MARTINEZ, BRANDY MARIE  ...
# 27              NaN   04112017        CLEMANS, ZACHARY LEE  ...
# 28              NaN   04182017            MARTINEZ, ARTURO  ...
# 29              NaN   04252017          CARSON, DAVID WADE  ...
# ...             ...        ...                         ...  ...
# 597785          NaN   09162017      SNUFFER, KENNETH DAVID  ...
# 597786          NaN   09192017            MARTINEZ, JUAN R  ...
# 597787          NaN   09192017        YOSTEN, BLAKE JOSEPH  ...
# 597788          NaN   09202017           CLICK, JAY MARCUS  ...
# 597789          NaN   09222017          PENSE, LARRY WAYNE  ...
# 597790          NaN   10042017              LARA, STEVEN D  ...
# 597791          NaN   10062017               SMITH, JACE E  ...
# 597792          NaN   10062017    BINNICKER, RICHARD ALLEN  ...
# 597793          NaN   10172017    CHAVEZ, FRANCISCO JAVIER  ...
# 597794          NaN   10172017             GUERRERO, REY S  ...
# 597795          NaN   10192017  SAVAGE, CROCKETT NATHANIEL  ...
# 597796          NaN   10192017              ADAMS, AARON J  ...
# 597797          NaN   10312017              SCOTT, JAMES A  ...
# 597798          NaN   11142017             HILL, RYAN WADE  ...
# 597799          NaN   11222017         THOMPSON, JARED W T  ...
# 597800          NaN   11282017        THOMAS, WESLEY WAYNE  ...
# 597801          NaN   11292017      JURGENSEN, JOSHUA MARK  ...
# 597802          NaN   12012017         MARSH, AARON ANDREW  ...
# 597803          NaN   12052017       KILLOUGH, BRUCE WAYNE  ...
# 597804          NaN   12062017        FAULKS, CARSON SLADE  ...
# 597805          NaN   12132017    ATKINS, BRANDON BUCHANAN  ...
# 597806          NaN   12152017            WILLIAMS, MARC R  ...
# 597807          NaN   12262017      WINSTEAD, CLINTON WADE  ...
# 597808          NaN   01132018             LILLEY, CLINTON  ...
# 597809          NaN   01232018              WOODS, JACOB R  ...
# 597810          NaN   01232018              ABEL, JUSTIN C  ...
# 597811          NaN   01232018         GRAY, MATTHEW BRYAN  ...
# 597812          NaN   01272018              MAYER, DAVID W  ...
# 597813          NaN   02132018     FRIESEN, FRANCISCO FEHR  ...
# 597814          NaN   02162018              BAUER, DAVID A  ...
#
#                          MAILCITYSTATE MAILCOUNTYCODE     MAILCOUNTY MAILZIP  \
# 0                     KILGORE TX 75662           0183          GREGG   75662
# 1                        POTH TX 78147           0493         WILSON   78147
# 2                HOUSTON TX 77076-2027           0201         HARRIS   77076
# 3                    BARTLETT TX 76511           0027           BELL   76511
# 4                    RINGLING OK 73456           0999   OUT OF STATE   73456
# 5                  SAYRE OK 73662-6080           0999   OUT OF STATE   73662
# 6                     ROSEBUD TX 76570           0145          FALLS   76570
# 7               RINGLING OK 73456-2014           0999   OUT OF STATE   73456
# 8                      DALLAS TX 75219           0113         DALLAS   75219
# 9                  CUNNINGHAM TX 75434           0277          LAMAR   75434
# 10                LUFKIN TX 75904-4331           0005       ANGELINA   75904
# 11                SAN ANTONIO TX 78218           0029          BEXAR   78218
# 12                     ODESSA TX 79762           0135          ECTOR   79762
# 13               TERRELL TX 75160-7592           0257        KAUFMAN   75160
# 14              COMANCHE TX 76442-7305           0093       COMANCHE   76442
# 15          STEPHENVILLE TX 76401-2860           0143          ERATH   76401
# 16                JOSHUA TX 76058-6060           0251        JOHNSON   76058
# 17                GOLDTHWAITE TX 76844           0333          MILLS   76844
# 18                      BANGS TX 76823           0049          BROWN   76823
# 19            GLADEWATER TX 75647-2415           0183          GREGG   75647
# 20                    CRESSON TX 76035           0221           HOOD   76035
# 21                 WAXAHACHIE TX 75165           0139          ELLIS   75165
# 22               KILLEEN TX 76549-9049           0027           BELL   76549
# 23                      BANGS TX 76823           0049          BROWN   76823
# 24             DEER PARK TX 77536-4704           0201         HARRIS   77536
# 25                    DALHART TX 79022           0111         DALLAM   79022
# 26               EL PASO TX 79912-2104           0141        EL PASO   79912
# 27              AMARILLO TX 79124-2319           0375         POTTER   79124
# 28               EL PASO TX 79912-2104           0141        EL PASO   79912
# 29                  HOWE TX 75459-4752           0181        GRAYSON   75459
# ...                                ...            ...            ...     ...
# 597785            WILLIS TX 77378-4347           0339     MONTGOMERY   77378
# 597786       SAN ANTONIO TX 78240-1007           0029          BEXAR   78240
# 597787          HEREFORD TX 79045-3020           0117     DEAF SMITH   79045
# 597788           MIDLAND TX 79706-5112           0329        MIDLAND   79706
# 597789          GLENPOOL OK 74033-3445           0999   OUT OF STATE   74033
# 597790           PHOENIX AZ 85034-2208           0999   OUT OF STATE   85034
# 597791          MOBEETIE TX 79061-4701           0483        WHEELER   79061
# 597792      MADISONVILLE TX 77864-1902           0313        MADISON   77864
# 597793        FORT WORTH TX 76107-1411           0439        TARRANT   76107
# 597794          HEREFORD TX 79045-0871           0117     DEAF SMITH   79045
# 597795      MARBLE FALLS TX 78654-7385           0053         BURNET   78654
# 597796           PHOENIX AZ 85034-2208           0999   OUT OF STATE   85034
# 597797           MIDLAND TX 79701-4417           0329        MIDLAND   79701
# 597798            ALPINE TX 79830-1049           0043       BREWSTER   79830
# 597799  DRIPPING SPRINGS TX 78620-2477           0209           HAYS   78620
# 597800             BOWIE TX 76230-5969           0337       MONTAGUE   76230
# 597801      VALLEY MILLS TX 76689-2963           0035         BOSQUE   76689
# 597802  DRIPPING SPRINGS TX 78620-4097           0209           HAYS   78620
# 597803            UTOPIA TX 78884-2602           0463         UVALDE   78884
# 597804             QUAIL TX 79251-4126           0087  COLLINGSWORTH   79251
# 597805        PLEASANTON TX 78064-1733           0013       ATASCOSA   78064
# 597806           PHOENIX AZ 85034-2208           0999   OUT OF STATE   85034
# 597807         GROESBECK TX 76642-2304           0293      LIMESTONE   76642
# 597808            ATHENS TX 75751-2236           0213      HENDERSON   75751
# 597809      VALLEY MILLS TX 76689-2963           0035         BOSQUE   76689
# 597810        SAN ANGELO TX 76901-9716           0451      TOM GREEN   76901
# 597811            ROWENA TX 76875-2608           0399        RUNNELS   76875
# 597812            YOAKUM TX 77995-6786           0285         LAVACA   77995
# 597813         LEVELLAND TX 79336-9124           0219        HOCKLEY   79336
# 597814       FLORESVILLE TX 78114-6076           0493         WILSON   78114
#
#          TELEPHONE LICSUBTYPE CEFLAG    last_name   first_name    FIRSTNAME
# 0       9039187899        NaN      N     WILLIAMS     WILLIAMS     WILLIAMS
# 1              NaN        NaN      N      GUEVARA      GUEVARA      GUEVARA
# 2       7136445566        NaN      N       BOWERS       BOWERS       BOWERS
# 3       2549852228        NaN      N       DEMSKY       DEMSKY       DEMSKY
# 4       5802765961        NaN      N     THOMPSON     THOMPSON     THOMPSON
# 5       5802250269        NaN      N       TUCKER       TUCKER       TUCKER
# 6       2815078713        NaN      N       COOPER       COOPER       COOPER
# 7       5802765961        NaN      N  BLANKENSHIP  BLANKENSHIP  BLANKENSHIP
# 8       2144091137        NaN      N        DAWES        DAWES        DAWES
# 9       9037825759        NaN      N       LESTER       LESTER       LESTER
# 10      9366749636        NaN      N      MANCILL      MANCILL      MANCILL
# 11      2106815425        NaN      N   HUDDLESTON   HUDDLESTON   HUDDLESTON
# 12      4322722266        NaN      N       JORDAN       JORDAN       JORDAN
# 13      4695951384        NaN      N        IRWIN        IRWIN        IRWIN
# 14      3253565950        NaN      N         HALL         HALL         HALL
# 15      2545928394        NaN      N        JAMES        JAMES        JAMES
# 16      8173200833        NaN      N       SIDAWI       SIDAWI       SIDAWI
# 17      3259386750        NaN      N        SMITH        SMITH        SMITH
# 18      3253727333        NaN      N     FERGUSON     FERGUSON     FERGUSON
# 19      9038453830        NaN      N     MCKINLEY     MCKINLEY     MCKINLEY
# 20      8173821530        NaN      N       SOWELL       SOWELL       SOWELL
# 21      9726930572        NaN      N       SEVIER       SEVIER       SEVIER
# 22      2542893216        NaN      N   SOMERVILLE   SOMERVILLE   SOMERVILLE
# 23      3253727333        NaN      N     BARCLIFT     BARCLIFT     BARCLIFT
# 24      2814797848        NaN      N         FORD         FORD         FORD
# 25      8062446776        NaN      N      SCHAFER      SCHAFER      SCHAFER
# 26      9153733887        NaN      N     MARTINEZ     MARTINEZ     MARTINEZ
# 27      8066833130        NaN      N      CLEMANS      CLEMANS      CLEMANS
# 28      9153733887        NaN      N     MARTINEZ     MARTINEZ     MARTINEZ
# 29      9035325501        NaN      N       CARSON       CARSON       CARSON
# ...            ...        ...    ...          ...          ...          ...
# 597785  9368566374          W      N      SNUFFER      SNUFFER      SNUFFER
# 597786  2106977114          M      N     MARTINEZ     MARTINEZ     MARTINEZ
# 597787  8063646140         KP      N       YOSTEN       YOSTEN       YOSTEN
# 597788  4326820703          W      N        CLICK        CLICK        CLICK
# 597789  9183223095          W      N        PENSE        PENSE        PENSE
# 597790  6024533252          M      N         LARA         LARA         LARA
# 597791  8068265975       KLPT      N        SMITH        SMITH        SMITH
# 597792  9363485838         PW      N    BINNICKER    BINNICKER    BINNICKER
# 597793  8178770866          M      N       CHAVEZ       CHAVEZ       CHAVEZ
# 597794  8063643109       KLPT      N     GUERRERO     GUERRERO     GUERRERO
# 597795  8306932340          P      N       SAVAGE       SAVAGE       SAVAGE
# 597796  6024533252          M      N        ADAMS        ADAMS        ADAMS
# 597797  4325578821          W      N        SCOTT        SCOTT        SCOTT
# 597798  4322942335        KLP      N         HILL         HILL         HILL
# 597799  5128944221         KP      N     THOMPSON     THOMPSON     THOMPSON
# 597800  9408726992          W      N       THOMAS       THOMAS       THOMAS
# 597801  2549326251        KPT      N    JURGENSEN    JURGENSEN    JURGENSEN
# 597802  5128584375          P      N        MARSH        MARSH        MARSH
# 597803  8309663456         KP      N     KILLOUGH     KILLOUGH     KILLOUGH
# 597804  8068981609      KLPTW      N       FAULKS       FAULKS       FAULKS
# 597805  8302812400        KPT      N       ATKINS       ATKINS       ATKINS
# 597806  6024533252          M      N     WILLIAMS     WILLIAMS     WILLIAMS
# 597807  2547293762          W      N     WINSTEAD     WINSTEAD     WINSTEAD
# 597808  9036752353        KLP      N       LILLEY       LILLEY       LILLEY
# 597809  2549326251          P      N        WOODS        WOODS        WOODS
# 597810  3259496607         KP      N         ABEL         ABEL         ABEL
# 597811  3254422331       KLPW      N         GRAY         GRAY         GRAY
# 597812  3612933168          P      N        MAYER        MAYER        MAYER
# 597813  8065980508          W      N      FRIESEN      FRIESEN      FRIESEN
# 597814  8303917338          W      N        BAUER        BAUER        BAUER
#
# [597815 rows x 22 columns]

# %% [markdown]
# ## 28. Can we be any more obnoxious in this assignment?
#
# Not only are we going to detect gender from first names, but we're also going to use a library that has the terrible name of [sex machine](https://github.com/ferhatelmas/sexmachine/). Once upon a time there was Ruby package named sex machine and everyone was like "come on are you six years old? is this how we do things?" and the guy was like "you're completely right I'm renaming it to [gender detector](https://github.com/bmuller/gender_detector)" and the world was Nice and Good again. Apparently Python didn't get the message.
#
# Except actually sexmachine doesn't work on Python 3 because it's from 300 BC so we're going to use a Python 3 fork called [gender guesser](https://pypi.python.org/pypi/gender-guesser/) (hooray!).
#
# #### Use `pip` or `pip3` to install gender-guesser.

# %%
# !pip install gender-guesser

# %% [markdown]
# #### Test to see that it works

# %%
import gender_guesser.detector as gender

detector = gender.Detector(case_sensitive=False)
detector.get_gender('David')

# %%
detector.get_gender('Jose')

# %%
detector.get_gender('Maria')

# %% [markdown]
# #### Use it on a dataframe
#
# To use something fancy like that on a dataframe, you use `.apply`. Check it out:

# %%
df['FIRSTNAME'].fillna('').apply(lambda name: detector.get_gender(name)).head()

# %% [markdown]
# ## 29. Calculate the gender of everyone's first name and save it to a column
#
# Confirm by see how many people of each gender we have

# %% [markdown]
# ## 30. We like taking risks - get rid of ambiguity
#
# * Combine the `mostly_female` into `female`
# * Combine the `mostly_male` into `male`
# * Replace `andy` (androgynous) and `unknown` with `NaN`
#
# you can get NaN not by making a string, but with `import numpy as np` and then using `np.nan`.

# %%
import numpy as np

# %% [markdown]
# ## 31. Do men or women have more licenses? What is the percentage of unknown genders?

# %% [markdown]
# ## 32. What are the popular unknown- or ambiguous gender first names?
#
# Yours might be different! Mine is a combination of actual ambiguity, cultural bias and dirty data.

# %% [markdown]
# ## 31. What are the most popular licenses for men? For women?

# %% [markdown]
# ## 32. What is the gender breakdown for Property Tax Appraiser? How about anything involving Tow Trucks?
#
# If you're in need, remember your good friend `.fillna(False)` to get rid of NaN values.

# %% [markdown]
# (By the way, what are those tow truck jobs?)

# %% [markdown]
# ## 33. Graph them!
#
# And let's **give them titles** so we know which is which.

# %% [markdown]
# ## 34. Calcuate the gender bias for profession
#
# I spent like an hour on this and then realized a super easy way to do it. Welcome to programming! I'll do this part for you.

# %%
# So when you do .value_counts(), it gives you an index and a value
df[df['GENDER'] == 'male'].LICTYPE.value_counts().head()

# %% [markdown]
# We did `pd.concat` to combine dataframes, but you can also use it to combine series (like the results of `value_counts()`). If you give it a few `value_counts()` and give it some column names it'll make something real nice.

# %%
# All of the values_counts() we will be combining
vc_series = [
    df[df['GENDER'] == 'male'].LICTYPE.value_counts(),
    df[df['GENDER'] == 'female'].LICTYPE.value_counts(),
    df[df['GENDER'].isnull()].LICTYPE.value_counts()
]
# You need axis=1 so it combines them as columns
gender_df = pd.concat(vc_series, axis=1)
gender_df.head()

# %%
# Turn "A/C Contractor" etc into an actual column instead of an index
gender_df.reset_index(inplace=True)
gender_df.head()

# %%
# Rename the columns appropriately
gender_df.columns = ["license", "male", "female", "unknown"]
# Clean up the NaN by replacing them with zeroes
gender_df.fillna(0, inplace=True)
gender_df.head()

# %% [markdown]
# ## 35. Add new columns for total licenses, percent known (not percent unknown!), percent male (of known), percent female (of known)
#
# And replace any `NaN`s with `0`.

# %% [markdown]
# ## 35. What 10 licenses with more than 2,000 people and over 75% known has the most male owners? The most female?

# %% [markdown]
# ## 36. Let's say you have to call a few people about being in a profession dominated by the other gender. What are their phone numbers?
#
# This will involve doing some research in one dataframe, then the other one. I didn't put an answer here because I'm interested in what you come up with!

# %% [markdown]
# ## PART FIVE: Violations
#
# ### 37. Read in **violations.csv** as `violations_df`, make sure it looks right

# %% [markdown]
# ### 38. Combine with your original licenses dataset dataframe to get phone numbers and addresses for each violation. Check that it is 90 rows, 28 columns.

# %% [markdown]
# ## 39. Find each violation involving a failure with records. Use a regular expression.

# %% [markdown]
# ## 40. How much money was each fine? Use a regular expression and .str.extract (we talked about it before!)
#
# Unfortunately large and helpful troubleshooting tip: `$` means "end of a line" in regex, so `.extract` isn't going to accept it as a dollar sign. You need to escape it by using `\$` instead.

# %% [markdown]
# ## 41. Clean those results (no commas, no dollar signs, and it should be an integer) and save it to a new column called `fine`
#
# `.replace` is for *entire cells*, you're interested in `.str.replace`, which treats each value like a string, not like a... pandas thing.
#
# `.astype(int)` will convert it into an integer for you.

# %% [markdown]
# ## 42. Which orders results in the top fines?

# %% [markdown]
# ## 43. Are you still here???
#
# I'm sure impressed.
