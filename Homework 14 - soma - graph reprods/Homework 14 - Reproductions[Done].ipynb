# %% [markdown]
# # Pandas and Illustrator
#
# **Do these in whatever order you'd like.** Feel free to do a bar graph, then skip ahead to some Buzzfeed line graphs, etc. Start in pandas, then once you save move on over to Illustrator.
#
# Do each group - NYT, Buzzfeed, FiveThirtyEight, Economist, Guardian - in a different notebook.  I'm only leaving spaces in these here so you can scroll through them more easily.
#
# Be sure to check out the other notebook for **tips and hints**.

# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('generic_poll_lead.csv')

# %%
def build_colors(row):
    if row['in_power'] == 'no':
        return 'yellow'
    elif row['in_power'] == 'yes':
        return 'grey'
    
colors = df.reset_index().apply(build_colors, axis = 1)

# %%
Ax = df.sort_values('year', ascending = True).plot(x= 'year', y = 'lead', kind='barh', width = 0.8, color = colors)
Ax.set_xticks([])

import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
plt.savefig('nyt1.pdf')

# %% [markdown]
# # NYT: Bar graphs
#
# Recreate the bar charts from [this piece](https://www.nytimes.com/2017/12/20/upshot/democrats-2018-congressional-elections-polling.html) and [this piece](https://www.nytimes.com/2017/12/27/business/the-robots-are-coming-and-sweden-is-fine.html) and [this piece](https://www.nytimes.com/2017/09/29/upshot/dont-forget-the-republicans-incumbency-advantage-in-2018.html).
#
# ![](images/sample-nyt.png)
#
# **Data:**
#
# * `generic_poll_lead.csv`
# * `social-spending.csv`
# * `cook_pvi.csv`

# %%
df = pd.read_csv('social-spending.csv')

# %%
df['Social Spending'] = df['Social Spending'].str.replace('%', '')

# %%
df['Social Spending'] = df['Social Spending'].astype(float)

# %%
df.sort_values(df['Social Spending'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Social Spending'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-17d3ab960614> in <module>
# ----> 1 df.sort_values(df['Social Spending'])
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Social Spending'

# %%
df = pd.read_csv('cook_pvi.csv')

df
# Out:
#           cook_pvi  pct_defeated
# 0   C+7 or greater            76
# 1       C+3 to C+7            63
# 2       C+1 to C+3            61
# 3       I+1 to C+1            35
# 4       I+1 to I+3            25
# 5       I+3 to I+5            18
# 6      I+5 to I+10             7
# 7  I+10 or greater             0

# %%
df.sort_values('pct_defeated', ascending = True).plot(kind='barh')

# %% [markdown]
# # Buzzfeed: Diversity in the Agriculture Department
#
# You are going to recreate the two line-graph visualizations in [this piece](https://www.buzzfeed.com/jsvine/agriculture-department-political-appointee-diversity) by the super-famous [Jeremy Singer-Vine](https://twitter.com/jsvine). If he can do it, you can too!
#
# ![](images/buzzfeed.png)
#
# **I've included the 100% beautiful, cleaned up data:** `gender-by-quarter.csv` and `diversity-by-quarter.csv`.
#
# Since there isn't much cleaning to do, this work is mostly going to be about **how to move between pandas/matplotlib and finish things up in Illustrator.**

# %%
df = pd.read_csv('diversity-by-quarter.csv')

# %%
df
# Out:
#     quarter            toa_group  count_all  count_minority  pct_minority
# 0   2006-09        all-permanent    1608157          521323     32.417419
# 1   2006-09  midlevel-appointees       2246             268     11.932324
# 2   2007-09        all-permanent    1618159          532756     32.923588
# 3   2007-09  midlevel-appointees       2315             259     11.187905
# 4   2008-09        all-permanent    1673249          560098     33.473679
# 5   2008-09  midlevel-appointees       2138             225     10.523854
# 6   2009-09        all-permanent    1757105          590216     33.590252
# 7   2009-09  midlevel-appointees       1767             454     25.693265
# 8   2009-12        all-permanent    1777356          596118     33.539595
# 9   2009-12  midlevel-appointees       1943             498     25.630468
# 10  2010-03        all-permanent    1784055          599888     33.624972
# 11  2010-03  midlevel-appointees       2012             526     26.143141
# 12  2010-06        all-permanent    1805245          610628     33.825215
# 13  2010-06  midlevel-appointees       2101             553     26.320800
# 14  2010-09        all-permanent    1831719          621210     33.914045
# 15  2010-09  midlevel-appointees       2136             570     26.685393
# 16  2010-12        all-permanent    1849354          627965     33.955911
# 17  2010-12  midlevel-appointees       2154             582     27.019499
# 18  2011-03        all-permanent    1852519          630697     34.045373
# 19  2011-03  midlevel-appointees       2173             596     27.427520
# 20  2011-06        all-permanent    1854973          632528     34.099041
# 21  2011-06  midlevel-appointees       2161             600     27.764924
# 22  2011-09        all-permanent    1856580          634270     34.163354
# 23  2011-09  midlevel-appointees       2107             589     27.954438
# 24  2011-12        all-permanent    1849768          633825     34.265108
# 25  2011-12  midlevel-appointees       2094             588     28.080229
# 26  2012-03        all-permanent    1844485          634270     34.387376
# 27  2012-03  midlevel-appointees       2117             596     28.153047
# 28  2012-06        all-permanent    1844059          636472     34.514731
# 29  2012-06  midlevel-appointees       2088             599     28.687739
# ..      ...                  ...        ...             ...           ...
# 42  2014-03        all-permanent    1812544          638014     35.199918
# 43  2014-03  midlevel-appointees       1986             617     31.067472
# 44  2014-06        all-permanent    1816252          642446     35.372074
# 45  2014-06  midlevel-appointees       1983             633     31.921331
# 46  2014-09        all-permanent    1825762          648205     35.503258
# 47  2014-09  midlevel-appointees       2069             691     33.397777
# 48  2014-12        all-permanent    1828217          649445     35.523409
# 49  2014-12  midlevel-appointees       2143             732     34.157723
# 50  2015-03        all-permanent    1822710          650027     35.662667
# 51  2015-03  midlevel-appointees       2204             750     34.029038
# 52  2015-06        all-permanent    1833620          656762     35.817781
# 53  2015-06  midlevel-appointees       2210             743     33.619910
# 54  2015-09        all-permanent    1848494          665108     35.981074
# 55  2015-09  midlevel-appointees       2242             744     33.184657
# 56  2015-12        all-permanent    1856870          669548     36.057882
# 57  2015-12  midlevel-appointees       2283             764     33.464739
# 58  2016-03        all-permanent    1847116          667669     36.146566
# 59  2016-03  midlevel-appointees       2271             757     33.333333
# 60  2016-06        all-permanent    1857544          674515     36.312195
# 61  2016-06  midlevel-appointees       2273             756     33.260009
# 62  2016-09        all-permanent    1868027          681179     36.465158
# 63  2016-09  midlevel-appointees       2251             733     32.563305
# 64  2016-12        all-permanent    1878935          688430     36.639373
# 65  2016-12  midlevel-appointees       2173             711     32.719742
# 66  2017-03        all-permanent    1876163          691647     36.864974
# 67  2017-03  midlevel-appointees        722              85     11.772853
# 68  2017-06        all-permanent    1874060          693383     36.998975
# 69  2017-06  midlevel-appointees       1045             119     11.387560
# 70  2017-09        all-permanent    1869986          694786     37.154610
# 71  2017-09  midlevel-appointees       1301             146     11.222137
#
# [72 rows x 5 columns]

# %%
df_permanent = df[df.toa_group == 'all-permanent']

# %%
df_permanent.plot(x='toa_group', y='pct_minority', kind='line')

# %%
df_midlevel = df[df.toa_group == 'midlevel-appointees']

# %%
df_midlevel.plot(x='toa_group', y='pct_minority', kind='line')

# %% [markdown]
# # FiveThirtyEight: What makes Nigel Richards the best at Scrabble?
#
# You are going to recreate the visualizations in [this piece](https://fivethirtyeight.com/features/what-makes-nigel-richards-the-best-scrabble-player-on-earth/) by [Oliver Roeder](https://twitter.com/ollie). This is one of my favorite series of charts in all of history!
#
# (When you break them down by divisions, though, don't draw the circles.)
#
# ![](images/sample-538.png)
#
# **I've included the data, but there's a little work to be done:**
#
# * `scrabble-point-spread.csv` - the points for and against each player at Nationals from one year (2013)
# * `scrabble-tournament.csv` - rating and division data for each player at Nationals from one year (2013)
# * `ranked-players-with-scores.csv` - the top 200 ranked players and their average points per game (2018)
#
# Note that the ranking data is from 2018 so the graph that uses it will look a bit different.

# %%
df1 = pd.read_csv('scrabble-point-spread.csv')

# %%
df2 = pd.read_csv('scrabble-tournament.csv')

# %%
df2
# Out:
#      Byes  Credits  Losses                     Name  New Rating  Old Rating  \
# 0     NaN      NaN       7           Nigel Richards        2196      2168.0
# 1     NaN      NaN       7    Komol Panyasophonlert        2070      2002.0
# 2     NaN      NaN       8            Will Anderson        2093      2054.0
# 3     NaN      NaN       9              Noah Walton        2063      2015.0
# 4     NaN      NaN      10          Kenji Matsumoto        2057      2023.0
# 5     NaN      NaN      10              Scott Appel        2001      1920.0
# 6     NaN      NaN      10              Mack Meller        2035      2014.0
# 7     NaN      NaN      11               Rafi Stern        2033      2030.0
# 8     NaN      NaN      11                Jesse Day        2022      2021.0
# 9     NaN      NaN      12             Dave Wiegand        2016      2000.0
# 10    NaN      NaN      12               Trip Payne        1883      1818.0
# 11    NaN      NaN      12  Conrad Bassett-Bouchard        2019      2022.0
# 12    NaN      NaN      12           Mark Pistolese        1848      1790.0
# 13    NaN      NaN      12             Rob Robinsky        1918      1883.0
# 14    NaN      NaN      12           Charles Reinke        1857      1760.0
# 15    NaN      NaN      12            Ian Weinstein        2024      2030.0
# 16    NaN      NaN      12          Peter Armstrong        1969      1948.0
# 17    NaN      NaN      13             Carl Johnson        1972      1967.0
# 18    NaN      NaN      13              Mike Frentz        1984      1990.0
# 19    NaN      NaN      13             Joel Sherman        1978      1974.0
# 20    NaN      NaN      13            Nigel Peltier        1852      1809.0
# 21    NaN      NaN      13            Thomas Reinke        1830      1758.0
# 22    NaN      NaN      13               Matt Canik        1861      1839.0
# 23    NaN      NaN      13              Maddy Kamen        1890      1839.0
# 24    NaN      NaN      13             Lou Cornelis        1853      1797.0
# 25    NaN      NaN      13               Chris Cree        1940      1938.0
# 26    NaN      NaN      13              Joe Gaspard        1817      1747.0
# 27    NaN      NaN      13           Erickson Smith        1836      1763.0
# 28    NaN      NaN      13         Timothy Bottorff        1809      1720.0
# 29    NaN      NaN      14          Cesar Del Solar        1956      1998.0
# ..    ...      ...     ...                      ...         ...         ...
# 451   NaN      NaN      17           Jean Zucherate         793       831.0
# 452   1.0      NaN      17            Kathy Johnson         606       595.0
# 453   NaN      NaN      17              Laurie Holz         774       786.0
# 454   NaN      NaN      17               Lois S Oda         778       800.0
# 455   1.0      NaN      17        Raina Gulbrandson         658       658.0
# 456   1.0      NaN      17            Desiree Engel         585       526.0
# 457   NaN      NaN      17           Pamela Pudelka         789       807.0
# 458   1.0      NaN      17             Jennifer Hay         713       774.0
# 459   NaN      NaN      17       Norman Weathers Jr         594       540.0
# 460   NaN      NaN      18              Norm Garvin         656       704.0
# 461   1.0      NaN      18              Paul Becker         712       799.0
# 462   NaN      NaN      18           Karen Kaminski         551       489.0
# 463   NaN      NaN      18           Percy Fernando         725       763.0
# 464   1.0      NaN      18          Rachel Gillette         712       828.0
# 465   NaN      NaN      18          Anna Marie Cook         631       652.0
# 466   NaN      NaN      18               Norman Wei         606       616.0
# 467   1.0      NaN      18           Nikki Hoffmann         583       601.0
# 468   NaN      NaN      19            Judy Troutman         565       576.0
# 469   1.0      NaN      19            Merran Dunlop         614       686.0
# 470   1.0      NaN      19   Murali Balasubramanyam         604       650.0
# 471   1.0      NaN      19           Michael Gincel         428       371.0
# 472   1.0      NaN      19             Dawn Mennear         506       531.0
# 473   1.0      NaN      19             Carmela Long         540       581.0
# 474   1.0      NaN      20            Janet Griesel         630       733.0
# 475   1.0      NaN      20             Jean Trotman         621       721.0
# 476   1.0      NaN      21             Rana Afeiche         667       807.0
# 477   4.0      NaN      18             Ruth Haywood         497       500.0
# 478   1.0      NaN      21        Douglas Patterson         580       801.0
# 479  11.0      NaN      12        Michael Krafchick         939      1074.0
# 480   1.0      NaN      23            Leanne Becker         392       497.0
#
#     Other Money  Perf Rating  Place  Player ID Prize Money  Seed  Spread  \
# 0           NaN       2356.0      1       6003     $10,000     1    1934
# 1           NaN       2372.0      2      20749      $3,000    11    1868
# 2           NaN       2264.0      3      19535      $2,000     2    1623
# 3           NaN       2239.0      4      18474      $1,000     8    1628
# 4           NaN       2212.0      5        583        $800     5    1671
# 5           NaN       2177.0      6         55        $700    27     746
# 6           NaN       2114.0      7      20383        $600     9     397
# 7           NaN       2033.0      8       2105        $500     3     960
# 8           NaN       2028.0      9      10129        $350     7     652
# 9           NaN       2087.0     10        728        $250    12    1153
# 10        $200E       2008.0     11       1389         NaN    53    1085
# 11          NaN       2012.0     12         10         NaN     6     838
# 12        $175E       1948.0     13       1385         NaN    59     744
# 13          NaN       2007.0     14       1534         NaN    32     721
# 14          NaN       2030.0     15      13512         NaN    67     694
# 15          NaN       1997.0     16       1847         NaN     3     638
# 16          NaN       2002.0     17         34         NaN    20     374
# 17          NaN       1977.0     18       1060         NaN    17     950
# 18          NaN       1995.0     19       1408         NaN    14     885
# 19          NaN       1991.0     20         53         NaN    15     824
# 20        $100E       1929.0     21       6969         NaN    55     680
# 21          NaN       1964.0     22      13511         NaN    69     679
# 22          NaN       1897.0     23        498         NaN    46     559
# 23          NaN       1993.0     24        346         NaN    46     487
# 24          NaN       1961.0     25        302         NaN    57     468
# 25          NaN       1935.0     26        435         NaN    23     464
# 26          NaN       1934.0     27       1529         NaN    72     435
# 27          NaN       1951.0     28       2433         NaN    66     307
# 28          NaN       1898.0     29      16519         NaN    75    -228
# 29          NaN       1872.0     30      13509         NaN    13    1089
# ..          ...          ...    ...        ...         ...   ...     ...
# 451         NaN        734.0     66       7424         NaN    48    -190
# 452         NaN        622.0     67        497         NaN    84    -246
# 453         NaN        770.0     68      20682         NaN    62    -330
# 454         NaN        754.0     69      10346         NaN    58    -428
# 455         NaN        653.0     70      19055         NaN    76    -517
# 456         NaN        599.0     71        425         NaN    90    -647
# 457         NaN        774.0     72      18722         NaN    53    -774
# 458         NaN        631.0     73      18072         NaN    66    -518
# 459         NaN        683.0     74      17161         NaN    88    -681
# 460         NaN        578.0     75      17722         NaN    73     161
# 461        $25E        546.0     76        953         NaN    59    -326
# 462         NaN        652.0     77      18462         NaN    93    -423
# 463         NaN        681.0     78       1887         NaN    68    -620
# 464         NaN        626.0     79      21078         NaN    51    -663
# 465         NaN        610.0     80       1768         NaN    78    -665
# 466         NaN        599.0     81      20637         NaN    82    -520
# 467         NaN        578.0     82      21117         NaN    83    -641
# 468         NaN        555.0     83      19057         NaN    86    -331
# 469         NaN        497.0     84       2203         NaN    74    -399
# 470         NaN        529.0     85      21136         NaN    80    -601
# 471         NaN        534.0     86      20701         NaN    95    -663
# 472         NaN        504.0     87      20994         NaN    89    -794
# 473         NaN        524.0     88      20717         NaN    85   -1018
# 474         NaN        457.0     89        541         NaN    70     219
# 475         NaN        472.0     90      18255         NaN    72    -793
# 476        $25E        361.0     91      17806         NaN    53    -506
# 477         NaN        496.0     92      21124         NaN    91   -1107
# 478         NaN        362.0     93      20410         NaN    57   -1311
# 479         NaN        668.0     94      18286         NaN     3    -508
# 480         NaN        237.0     95      20918         NaN    92   -1650
#
#      Ties  Tournament ID  Wins    division
# 0     NaN           8163    24  Division 1
# 1     NaN           8163    24  Division 1
# 2     NaN           8163    23  Division 1
# 3     NaN           8163    22  Division 1
# 4     NaN           8163    21  Division 1
# 5     NaN           8163    21  Division 1
# 6     1.0           8163    20  Division 1
# 7     NaN           8163    20  Division 1
# 8     1.0           8163    19  Division 1
# 9     NaN           8163    19  Division 1
# 10    NaN           8163    19  Division 1
# 11    NaN           8163    19  Division 1
# 12    NaN           8163    19  Division 1
# 13    NaN           8163    19  Division 1
# 14    NaN           8163    19  Division 1
# 15    NaN           8163    19  Division 1
# 16    NaN           8163    19  Division 1
# 17    NaN           8163    18  Division 1
# 18    NaN           8163    18  Division 1
# 19    NaN           8163    18  Division 1
# 20    NaN           8163    18  Division 1
# 21    NaN           8163    18  Division 1
# 22    NaN           8163    18  Division 1
# 23    NaN           8163    18  Division 1
# 24    NaN           8163    18  Division 1
# 25    NaN           8163    18  Division 1
# 26    NaN           8163    18  Division 1
# 27    NaN           8163    18  Division 1
# 28    NaN           8163    18  Division 1
# 29    NaN           8163    17  Division 1
# ..    ...            ...   ...         ...
# 451   NaN           8163    14  Division 4
# 452   NaN           8163    13  Division 4
# 453   NaN           8163    14  Division 4
# 454   NaN           8163    14  Division 4
# 455   NaN           8163    13  Division 4
# 456   NaN           8163    13  Division 4
# 457   NaN           8163    14  Division 4
# 458   1.0           8163    12  Division 4
# 459   1.0           8163    13  Division 4
# 460   NaN           8163    13  Division 4
# 461   NaN           8163    12  Division 4
# 462   NaN           8163    13  Division 4
# 463   NaN           8163    13  Division 4
# 464   NaN           8163    12  Division 4
# 465   NaN           8163    13  Division 4
# 466   1.0           8163    12  Division 4
# 467   1.0           8163    11  Division 4
# 468   NaN           8163    12  Division 4
# 469   NaN           8163    11  Division 4
# 470   NaN           8163    11  Division 4
# 471   NaN           8163    11  Division 4
# 472   NaN           8163    11  Division 4
# 473   NaN           8163    11  Division 4
# 474   NaN           8163    10  Division 4
# 475   NaN           8163    10  Division 4
# 476   NaN           8163     9  Division 4
# 477   NaN           8163     9  Division 4
# 478   1.0           8163     8  Division 4
# 479   NaN           8163     8  Division 4
# 480   2.0           8163     5  Division 4
#
# [481 rows x 17 columns]

# %%
df_merged = df1.merge(df2, left_on='player_id', right_on=df2['Player ID'])

# %%
df_merged
# Out:
#      player_id  points_against  points_for  tournament_id  Byes  Credits  \
# 0         6003             381         443           8163   NaN      NaN
# 1        20749             375         435           8163   NaN      NaN
# 2        19535             391         443           8163   NaN      NaN
# 3        18474             386         439           8163   NaN      NaN
# 4          583             396         450           8163   NaN      NaN
# 5           55             400         424           8163   NaN      NaN
# 6        20383             402         415           8163   NaN      NaN
# 7         2105             403         434           8163   NaN      NaN
# 8        10129             398         419           8163   NaN      NaN
# 9          728             386         424           8163   NaN      NaN
# 10        1389             377         412           8163   NaN      NaN
# 11          10             403         430           8163   NaN      NaN
# 12        1385             392         416           8163   NaN      NaN
# 13        1534             401         424           8163   NaN      NaN
# 14       13512             403         425           8163   NaN      NaN
# 15        1847             390         411           8163   NaN      NaN
# 16          34             410         422           8163   NaN      NaN
# 17        1060             395         425           8163   NaN      NaN
# 18        1408             390         418           8163   NaN      NaN
# 19          53             391         418           8163   NaN      NaN
# 20        6969             401         423           8163   NaN      NaN
# 21       13511             386         408           8163   NaN      NaN
# 22         498             403         421           8163   NaN      NaN
# 23         346             396         412           8163   NaN      NaN
# 24         302             395         411           8163   NaN      NaN
# 25         435             395         410           8163   NaN      NaN
# 26        1529             389         403           8163   NaN      NaN
# 27        2433             403         413           8163   NaN      NaN
# 28       16519             406         399           8163   NaN      NaN
# 29       13509             392         427           8163   NaN      NaN
# ..         ...             ...         ...            ...   ...      ...
# 451       7424             352         346           8163   NaN      NaN
# 452        497             348         338           8163   1.0      NaN
# 453      20682             356         345           8163   NaN      NaN
# 454      10346             348         334           8163   NaN      NaN
# 455      19055             369         350           8163   1.0      NaN
# 456        425             334         311           8163   1.0      NaN
# 457      18722             364         339           8163   NaN      NaN
# 458      18072             365         346           8163   1.0      NaN
# 459      17161             356         334           8163   NaN      NaN
# 460      17722             345         351           8163   NaN      NaN
# 461        953             348         336           8163   1.0      NaN
# 462      18462             328         315           8163   NaN      NaN
# 463       1887             364         344           8163   NaN      NaN
# 464      21078             356         332           8163   1.0      NaN
# 465       1768             361         339           8163   NaN      NaN
# 466      20637             353         336           8163   NaN      NaN
# 467      21117             361         337           8163   1.0      NaN
# 468      19057             343         332           8163   NaN      NaN
# 469       2203             349         335           8163   1.0      NaN
# 470      21136             363         341           8163   1.0      NaN
# 471      20701             356         332           8163   1.0      NaN
# 472      20994             350         322           8163   1.0      NaN
# 473      20717             367         331           8163   1.0      NaN
# 474        541             345         351           8163   1.0      NaN
# 475      18255             351         323           8163   1.0      NaN
# 476      17806             357         338           8163   1.0      NaN
# 477      21124             361         324           8163   4.0      NaN
# 478      20410             360         315           8163   1.0      NaN
# 479      18286             344         341           8163  11.0      NaN
# 480      20918             370         314           8163   1.0      NaN
#
#      Losses                     Name  New Rating  Old Rating  ... Perf Rating  \
# 0         7           Nigel Richards        2196      2168.0  ...      2356.0
# 1         7    Komol Panyasophonlert        2070      2002.0  ...      2372.0
# 2         8            Will Anderson        2093      2054.0  ...      2264.0
# 3         9              Noah Walton        2063      2015.0  ...      2239.0
# 4        10          Kenji Matsumoto        2057      2023.0  ...      2212.0
# 5        10              Scott Appel        2001      1920.0  ...      2177.0
# 6        10              Mack Meller        2035      2014.0  ...      2114.0
# 7        11               Rafi Stern        2033      2030.0  ...      2033.0
# 8        11                Jesse Day        2022      2021.0  ...      2028.0
# 9        12             Dave Wiegand        2016      2000.0  ...      2087.0
# 10       12               Trip Payne        1883      1818.0  ...      2008.0
# 11       12  Conrad Bassett-Bouchard        2019      2022.0  ...      2012.0
# 12       12           Mark Pistolese        1848      1790.0  ...      1948.0
# 13       12             Rob Robinsky        1918      1883.0  ...      2007.0
# 14       12           Charles Reinke        1857      1760.0  ...      2030.0
# 15       12            Ian Weinstein        2024      2030.0  ...      1997.0
# 16       12          Peter Armstrong        1969      1948.0  ...      2002.0
# 17       13             Carl Johnson        1972      1967.0  ...      1977.0
# 18       13              Mike Frentz        1984      1990.0  ...      1995.0
# 19       13             Joel Sherman        1978      1974.0  ...      1991.0
# 20       13            Nigel Peltier        1852      1809.0  ...      1929.0
# 21       13            Thomas Reinke        1830      1758.0  ...      1964.0
# 22       13               Matt Canik        1861      1839.0  ...      1897.0
# 23       13              Maddy Kamen        1890      1839.0  ...      1993.0
# 24       13             Lou Cornelis        1853      1797.0  ...      1961.0
# 25       13               Chris Cree        1940      1938.0  ...      1935.0
# 26       13              Joe Gaspard        1817      1747.0  ...      1934.0
# 27       13           Erickson Smith        1836      1763.0  ...      1951.0
# 28       13         Timothy Bottorff        1809      1720.0  ...      1898.0
# 29       14          Cesar Del Solar        1956      1998.0  ...      1872.0
# ..      ...                      ...         ...         ...  ...         ...
# 451      17           Jean Zucherate         793       831.0  ...       734.0
# 452      17            Kathy Johnson         606       595.0  ...       622.0
# 453      17              Laurie Holz         774       786.0  ...       770.0
# 454      17               Lois S Oda         778       800.0  ...       754.0
# 455      17        Raina Gulbrandson         658       658.0  ...       653.0
# 456      17            Desiree Engel         585       526.0  ...       599.0
# 457      17           Pamela Pudelka         789       807.0  ...       774.0
# 458      17             Jennifer Hay         713       774.0  ...       631.0
# 459      17       Norman Weathers Jr         594       540.0  ...       683.0
# 460      18              Norm Garvin         656       704.0  ...       578.0
# 461      18              Paul Becker         712       799.0  ...       546.0
# 462      18           Karen Kaminski         551       489.0  ...       652.0
# 463      18           Percy Fernando         725       763.0  ...       681.0
# 464      18          Rachel Gillette         712       828.0  ...       626.0
# 465      18          Anna Marie Cook         631       652.0  ...       610.0
# 466      18               Norman Wei         606       616.0  ...       599.0
# 467      18           Nikki Hoffmann         583       601.0  ...       578.0
# 468      19            Judy Troutman         565       576.0  ...       555.0
# 469      19            Merran Dunlop         614       686.0  ...       497.0
# 470      19   Murali Balasubramanyam         604       650.0  ...       529.0
# 471      19           Michael Gincel         428       371.0  ...       534.0
# 472      19             Dawn Mennear         506       531.0  ...       504.0
# 473      19             Carmela Long         540       581.0  ...       524.0
# 474      20            Janet Griesel         630       733.0  ...       457.0
# 475      20             Jean Trotman         621       721.0  ...       472.0
# 476      21             Rana Afeiche         667       807.0  ...       361.0
# 477      18             Ruth Haywood         497       500.0  ...       496.0
# 478      21        Douglas Patterson         580       801.0  ...       362.0
# 479      12        Michael Krafchick         939      1074.0  ...       668.0
# 480      23            Leanne Becker         392       497.0  ...       237.0
#
#      Place  Player ID  Prize Money Seed  Spread  Ties  Tournament ID  Wins  \
# 0        1       6003      $10,000    1    1934   NaN           8163    24
# 1        2      20749       $3,000   11    1868   NaN           8163    24
# 2        3      19535       $2,000    2    1623   NaN           8163    23
# 3        4      18474       $1,000    8    1628   NaN           8163    22
# 4        5        583         $800    5    1671   NaN           8163    21
# 5        6         55         $700   27     746   NaN           8163    21
# 6        7      20383         $600    9     397   1.0           8163    20
# 7        8       2105         $500    3     960   NaN           8163    20
# 8        9      10129         $350    7     652   1.0           8163    19
# 9       10        728         $250   12    1153   NaN           8163    19
# 10      11       1389          NaN   53    1085   NaN           8163    19
# 11      12         10          NaN    6     838   NaN           8163    19
# 12      13       1385          NaN   59     744   NaN           8163    19
# 13      14       1534          NaN   32     721   NaN           8163    19
# 14      15      13512          NaN   67     694   NaN           8163    19
# 15      16       1847          NaN    3     638   NaN           8163    19
# 16      17         34          NaN   20     374   NaN           8163    19
# 17      18       1060          NaN   17     950   NaN           8163    18
# 18      19       1408          NaN   14     885   NaN           8163    18
# 19      20         53          NaN   15     824   NaN           8163    18
# 20      21       6969          NaN   55     680   NaN           8163    18
# 21      22      13511          NaN   69     679   NaN           8163    18
# 22      23        498          NaN   46     559   NaN           8163    18
# 23      24        346          NaN   46     487   NaN           8163    18
# 24      25        302          NaN   57     468   NaN           8163    18
# 25      26        435          NaN   23     464   NaN           8163    18
# 26      27       1529          NaN   72     435   NaN           8163    18
# 27      28       2433          NaN   66     307   NaN           8163    18
# 28      29      16519          NaN   75    -228   NaN           8163    18
# 29      30      13509          NaN   13    1089   NaN           8163    17
# ..     ...        ...          ...  ...     ...   ...            ...   ...
# 451     66       7424          NaN   48    -190   NaN           8163    14
# 452     67        497          NaN   84    -246   NaN           8163    13
# 453     68      20682          NaN   62    -330   NaN           8163    14
# 454     69      10346          NaN   58    -428   NaN           8163    14
# 455     70      19055          NaN   76    -517   NaN           8163    13
# 456     71        425          NaN   90    -647   NaN           8163    13
# 457     72      18722          NaN   53    -774   NaN           8163    14
# 458     73      18072          NaN   66    -518   1.0           8163    12
# 459     74      17161          NaN   88    -681   1.0           8163    13
# 460     75      17722          NaN   73     161   NaN           8163    13
# 461     76        953          NaN   59    -326   NaN           8163    12
# 462     77      18462          NaN   93    -423   NaN           8163    13
# 463     78       1887          NaN   68    -620   NaN           8163    13
# 464     79      21078          NaN   51    -663   NaN           8163    12
# 465     80       1768          NaN   78    -665   NaN           8163    13
# 466     81      20637          NaN   82    -520   1.0           8163    12
# 467     82      21117          NaN   83    -641   1.0           8163    11
# 468     83      19057          NaN   86    -331   NaN           8163    12
# 469     84       2203          NaN   74    -399   NaN           8163    11
# 470     85      21136          NaN   80    -601   NaN           8163    11
# 471     86      20701          NaN   95    -663   NaN           8163    11
# 472     87      20994          NaN   89    -794   NaN           8163    11
# 473     88      20717          NaN   85   -1018   NaN           8163    11
# 474     89        541          NaN   70     219   NaN           8163    10
# 475     90      18255          NaN   72    -793   NaN           8163    10
# 476     91      17806          NaN   53    -506   NaN           8163     9
# 477     92      21124          NaN   91   -1107   NaN           8163     9
# 478     93      20410          NaN   57   -1311   1.0           8163     8
# 479     94      18286          NaN    3    -508   NaN           8163     8
# 480     95      20918          NaN   92   -1650   2.0           8163     5
#
#        division
# 0    Division 1
# 1    Division 1
# 2    Division 1
# 3    Division 1
# 4    Division 1
# 5    Division 1
# 6    Division 1
# 7    Division 1
# 8    Division 1
# 9    Division 1
# 10   Division 1
# 11   Division 1
# 12   Division 1
# 13   Division 1
# 14   Division 1
# 15   Division 1
# 16   Division 1
# 17   Division 1
# 18   Division 1
# 19   Division 1
# 20   Division 1
# 21   Division 1
# 22   Division 1
# 23   Division 1
# 24   Division 1
# 25   Division 1
# 26   Division 1
# 27   Division 1
# 28   Division 1
# 29   Division 1
# ..          ...
# 451  Division 4
# 452  Division 4
# 453  Division 4
# 454  Division 4
# 455  Division 4
# 456  Division 4
# 457  Division 4
# 458  Division 4
# 459  Division 4
# 460  Division 4
# 461  Division 4
# 462  Division 4
# 463  Division 4
# 464  Division 4
# 465  Division 4
# 466  Division 4
# 467  Division 4
# 468  Division 4
# 469  Division 4
# 470  Division 4
# 471  Division 4
# 472  Division 4
# 473  Division 4
# 474  Division 4
# 475  Division 4
# 476  Division 4
# 477  Division 4
# 478  Division 4
# 479  Division 4
# 480  Division 4
#
# [481 rows x 21 columns]

# %%
def build_colors(row):
    if row['division'] == 'Division 1':
        return 'red'
    elif row['division'] == 'Division 2':
        return 'yellow'
    elif row['division'] == 'Division 3':
        return 'green'
    elif row['division'] == 'Division 4':
        return 'blue'
    
colors = df_merged.reset_index().apply(build_colors, axis = 1)

# %%
# df_merged.plot(x='points_for', y = 'points_against', kind='scatter')

df_merged.plot(x='points_for', y='points_against', kind='scatter', color = colors)

# %% [markdown]
# # The Economist
#
# Recreate the donut chart from [this piece](https://www.economist.com/blogs/graphicdetail/2012/07/daily-chart-0) even though [they're terrible](https://peltiertech.com/chart-busters-the-economist-doesnt-read-forbes/).
#
# ![](images/economist.png)
#
# In fact, the pies are _so terrible_ we're going to **recreate the [revised chart](https://peltiertech.com/chart-busters-the-economist-doesnt-read-forbes/), too**. The important thing about it is that while the original chart focuses on the actual values in 2007 and 2011, the arrow chart reduces those values to **just the change**, which is (arguably) the important part.
#
# ![](images/econ-revised.png)
#
# The revised chart is ugly, though, so we're going to make it look nicer.
#
# 1. Slightly change the chart type (See Homework Hints file)
# 2. Change the colors (Make it match the Economist)
# 3. Change any other styles/font/etc (Make it match the Economist
# 4. Order the bars (Order by what? Up to you.)
#
# **Data:**
#
# * `bank-profits.csv`

# %%
df = pd.read_csv('bank-profits.csv')

# %%
df.plot(x='region', y='year-2007', kind='pie')

# %%
df.plot(x='region', y='year-2011', kind='pie')

# %%
df.plot(y='year-2007', x='region', kind='barh')

# %%
df.plot(y='year-2011', x='region', kind='barh')

# %%
fig, ax = plt.subplots()
ax.hlines(xmin=[1, 2, 3, 4], xmax=[7, 8, 9, 20], y=[1, 2, 3, 4])

# %% [markdown]
# # The Guardian
#
# We'll be recreating a single graph each from
#
# 1. [this piece](https://www.theguardian.com/news/datablog/2018/jan/26/no-equality-in-the-honours-two-thirds-of-australia-day-awards-go-to-men)
# 2. and [this piece](https://www.theguardian.com/inequality/datablog/2017/jul/17/which-countries-most-and-least-committed-to-reducing-inequality-oxfam-dfi)
# 3. and [this piece](https://www.theguardian.com/money/datablog/2017/jan/06/tracking-the-cost-uk-and-european-commuter-rail-fares-compared-in-data)
#
# ![](images/guardian.png)
#
# We'll be using skills from the Economist revision, so **please do that one first!**
#
# **Data:**
#
# * `order-of-australia.csv`
# * `oxfam.csv`
# * `commute.csv`
