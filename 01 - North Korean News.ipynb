# %% [markdown]
# # North Korean News
#
# Scrape the North Korean news agency http://kcna.kp
#
# Save a CSV called `nk-news.csv`. This file should include:
#
# * The **article headline**
# * The value of **`onclick`** (they don't have normal links)
# * The **article ID** (for example, the article ID for `fn_showArticle("AR0125885", "", "NT00", "L")` is `AR0125885`
#
# The last part is easiest using pandas. Be sure you don't save the index!
#
# * _**Tip:** If you're using requests+BeautifulSoup, you can always look at response.text to see if the page looks like what you think it looks like_
# * _**Tip:** Check your URL to make sure it is what you think it should be!_
# * _**Tip:** Does it look different if you scrape with BeautifulSoup compared to if you scrape it with Selenium?_
# * _**Tip:** For the last part, how do you pull out part of a string from a longer string?_
# * _**Tip:** `expand=False` is helpful if you want to assign a single new column when extracting_
# * _**Tip:** `(` and `)` mean something special in regular expressions, so you have to say "no really seriously I mean `(`" by using `\(` instead_
# * _**Tip:** if your `.*` is taking up too much stuff, you can try `.*?` instead, which instead of "take as much as possible" it means "take only as much as needed"_

# %%
import requests
from bs4 import BeautifulSoup

import re

import pandas as pd

response = requests.get('http://kcna.kp/kcna.user.home.retrieveHomeInfoList.kcmsf;jsessionid=986E6911A7A5C7099544024C67C74C1A')
soup_doc = BeautifulSoup(response.text)

# %%
headlines = (soup_doc.find_all('a', class_='titlebet'))
for headline in headlines:
    print(headline.text)
    

onclicks = (soup_doc.find_all('a', class_='titlebet'))
for onclick in onclicks:
    print(headline['onclick'])
# Out:
# Committees for Election of Deputies to Province (Municipality), City (District) and County Assemblies Start Work in DPRK
# Greetings to Seychellois President
# Venezuelan City's Highest Order Awarded to Supreme Leader Kim Jong Un
# Xi Jinping to Visit DPRK
# Kim Jae Ryong Inspects Tokchon Area Coal-Mining Complex
# Double-Dealing Tactics Will Never Work: KCNA Commentary
# Central Election Guidance Committee Formed in DPRK
# Congratulations to President of Kazakhstan
# Greetings to Philippine President
# KCNA Commentary Rebukes Japan's Attachment to "Flag of Rising Sun Shedding Rays"
# Results of 2018-2019 DPRK Premier Football League (15)
# Results of 2018-2019 DPRK Women's Premier Football League (13)
# Results of AFC Cup
# Results of 2018-2019 DPRK Premier Football League (14)
# Road Relay Held in DPRK
# Pyongyang Int'l Sci-Tech Exhibition of Health and Medical Appliances Closes
# Pyongyang International Sci-Tech Exhibition of Health and Medical Appliances Opens
# Tour by Super-light Planes Popular in DPRK
# MOU Signed between DPRK and Russia
# Masikryong Ski Resort
# Tour of Historical Sites in Kangso Area Begins
# Scenic Mt Kumgang of Korea
# "Unbangul"-trademarked Musical Instruments Popular in DPRK
# Art Performance Given by Art Group Members of Korean Art Association of Disabled
# National Art Exhibition Opens
# Piano Concert Held by Students of Kim Won Gyun University of Music
# Supreme Leader Kim Jong Un Receives Personal Letter from U.S. President Donald Trump
# President Xi Jinping Leaves Here
# DPRK Culture Exhibition Held in China
# Events Held Abroad
# Implementation of June 12 DPRK-U.S. Joint Statement Demanded
# President Kim Il Sung to Be Remembered in Tanzania
# Indian Personages Issue Joint Statement
# Korean People's Struggle for Peace, Prosperity and Reunification Supported by Foreign Figures
# First Anniversary of June 12 DPRK-U.S. Joint Statement Marked Abroad
# President Kim Il Sung to Be Remembered in Venezuela
# Bringing about Heyday of Peace, Prosperity and Reunification Called for
# National Reunification Institute Issues Detailed Report on Struggle to Dissolve LKP
# Fate of DPRK-U.S. Joint Statement: Spokesperson for Ministry of Foreign Affairs of DPRK
# Use of Strength Is Not at All Monopoly of U.S.: Policy Research Director of Institute for American Studies, FM of DPRK
# CPRC Reunification and Agitation Department Exposes Sordid Nature of LKP
# C.C., AINDF Calls for Unity to Eliminate Evil-doing Conservative Forces
# Workers in North and South Call for Implementing North-South Declarations
# Rodong Sinmun Calls for Greeting Forthcoming Election with High Enthusiasm
# Review of Rodong Sinmun
# Press Review
# Press Review
# Press Review
# Rodong Sinmun on Preserving Juche Character and National Character
# Newspapers Warmly Welcome Goodwill Envoy of Fraternal Chinese People
# Struggle for Uprooting Deep-Seated Evils Called for in S. Korea
# S. Korean Newspaper Sneers at LKP
# Struggle for Uprooting Deep-Seated Evils Called for
# South Korean Students' Group for Studying Supreme Leader Kim Jong Un to Publish Study Results
# Overseas Koreans Call for Setting Up Special Team for Inquiry into Sewol Disaster
# Traitor Hwang Kyo An Gets Cold Reception
# DPRK's Citizens' Favorite Songs Introduced by S. Korean Newspaper
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")
# fn_showArticle("AR0125707", "", "NT02", "L")

# %%
rows = []

for headline in headlines:
    
    row = {}
    try:
        row['Headline'] = headline.text
    except:
        pass
    try:
        row['Onclick value'] = headline['onclick']
    except:
        pass
    
    rows.append(row)

df = pd.DataFrame(rows)
df
# Out:
#                                               Headline  \
# 0    Committees for Election of Deputies to Provinc...
# 1                   Greetings to Seychellois President
# 2    Venezuelan City's Highest Order Awarded to Sup...
# 3                             Xi Jinping to Visit DPRK
# 4    Kim Jae Ryong Inspects Tokchon Area Coal-Minin...
# 5    Double-Dealing Tactics Will Never Work: KCNA C...
# 6    Central Election Guidance Committee Formed in ...
# 7           Congratulations to President of Kazakhstan
# 8                    Greetings to Philippine President
# 9    KCNA Commentary Rebukes Japan's Attachment to ...
# 10   Results of 2018-2019 DPRK Premier Football Lea...
# 11   Results of 2018-2019 DPRK Women's Premier Foot...
# 12                                  Results of AFC Cup
# 13   Results of 2018-2019 DPRK Premier Football Lea...
# 14                             Road Relay Held in DPRK
# 15   Pyongyang Int'l Sci-Tech Exhibition of Health ...
# 16   Pyongyang International Sci-Tech Exhibition of...
# 17          Tour by Super-light Planes Popular in DPRK
# 18                  MOU Signed between DPRK and Russia
# 19                               Masikryong Ski Resort
# 20      Tour of Historical Sites in Kangso Area Begins
# 21                          Scenic Mt Kumgang of Korea
# 22   "Unbangul"-trademarked Musical Instruments Pop...
# 23   Art Performance Given by Art Group Members of ...
# 24                       National Art Exhibition Opens
# 25   Piano Concert Held by Students of Kim Won Gyun...
# 26   Supreme Leader Kim Jong Un Receives Personal L...
# 27                    President Xi Jinping Leaves Here
# 28   Supreme Leader Kim Jong Un Hosts Luncheon for ...
# 29   Xi Jinping Places Floral Basket at Friendship ...
# ..                                                 ...
# 79        Cypriot and Austrian Bodies Issue Statements
# 80               DPRK Culture Exhibition Held in China
# 81                                  Events Held Abroad
# 82   Implementation of June 12 DPRK-U.S. Joint Stat...
# 83   President Kim Il Sung to Be Remembered in Tanz...
# 84             Indian Personages Issue Joint Statement
# 85   Korean People's Struggle for Peace, Prosperity...
# 86   First Anniversary of June 12 DPRK-U.S. Joint S...
# 87   President Kim Il Sung to Be Remembered in Vene...
# 88   Bringing about Heyday of Peace, Prosperity and...
# 89   National Reunification Institute Issues Detail...
# 90   Fate of DPRK-U.S. Joint Statement: Spokesperso...
# 91   Use of Strength Is Not at All Monopoly of U.S....
# 92   CPRC Reunification and Agitation Department Ex...
# 93   C.C., AINDF Calls for Unity to Eliminate Evil-...
# 94   Workers in North and South Call for Implementi...
# 95   Rodong Sinmun Calls for Greeting Forthcoming E...
# 96                             Review of Rodong Sinmun
# 97                                        Press Review
# 98                                        Press Review
# 99                                        Press Review
# 100  Rodong Sinmun on Preserving Juche Character an...
# 101  Newspapers Warmly Welcome Goodwill Envoy of Fr...
# 102  Struggle for Uprooting Deep-Seated Evils Calle...
# 103                  S. Korean Newspaper Sneers at LKP
# 104  Struggle for Uprooting Deep-Seated Evils Calle...
# 105  South Korean Students' Group for Studying Supr...
# 106  Overseas Koreans Call for Setting Up Special T...
# 107           Traitor Hwang Kyo An Gets Cold Reception
# 108  DPRK's Citizens' Favorite Songs Introduced by ...
#
#                                     Onclick value
# 0    fn_showArticle("AR0126485", "", "NT21", "L")
# 1    fn_showArticle("AR0126295", "", "NT21", "L")
# 2    fn_showArticle("AR0126287", "", "NT21", "L")
# 3    fn_showArticle("AR0126286", "", "NT21", "L")
# 4    fn_showArticle("AR0126281", "", "NT21", "L")
# 5    fn_showArticle("AR0126277", "", "NT21", "L")
# 6    fn_showArticle("AR0126169", "", "NT21", "L")
# 7    fn_showArticle("AR0126127", "", "NT21", "L")
# 8    fn_showArticle("AR0126118", "", "NT21", "L")
# 9    fn_showArticle("AR0126117", "", "NT21", "L")
# 10   fn_showArticle("AR0126504", "", "NT11", "L")
# 11   fn_showArticle("AR0126454", "", "NT11", "L")
# 12   fn_showArticle("AR0126353", "", "NT11", "L")
# 13   fn_showArticle("AR0126278", "", "NT11", "L")
# 14   fn_showArticle("AR0126227", "", "NT11", "L")
# 15   fn_showArticle("AR0126425", "", "NT09", "L")
# 16   fn_showArticle("AR0126283", "", "NT09", "L")
# 17   fn_showArticle("AR0124762", "", "NT19", "L")
# 18   fn_showArticle("AR0122941", "", "NT19", "L")
# 19   fn_showArticle("AR0121949", "", "NT19", "L")
# 20   fn_showArticle("AR0121709", "", "NT19", "L")
# 21   fn_showArticle("AR0120090", "", "NT19", "L")
# 22   fn_showArticle("AR0126072", "", "NT12", "L")
# 23   fn_showArticle("AR0126459", "", "NT12", "L")
# 24   fn_showArticle("AR0126318", "", "NT12", "L")
# 25   fn_showArticle("AR0126163", "", "NT12", "L")
# 26   fn_showArticle("AR0126460", "", "NT00", "L")
# 27   fn_showArticle("AR0126435", "", "NT00", "L")
# 28   fn_showArticle("AR0126433", "", "NT00", "L")
# 29   fn_showArticle("AR0126423", "", "NT00", "L")
# ..                                            ...
# 79   fn_showArticle("AR0126486", "", "NT06", "L")
# 80   fn_showArticle("AR0126463", "", "NT06", "L")
# 81   fn_showArticle("AR0126461", "", "NT06", "L")
# 82   fn_showArticle("AR0126429", "", "NT06", "L")
# 83   fn_showArticle("AR0126487", "", "NT06", "L")
# 84   fn_showArticle("AR0126484", "", "NT06", "L")
# 85   fn_showArticle("AR0126462", "", "NT06", "L")
# 86   fn_showArticle("AR0126430", "", "NT06", "L")
# 87   fn_showArticle("AR0126428", "", "NT06", "L")
# 88   fn_showArticle("AR0126222", "", "NT17", "L")
# 89   fn_showArticle("AR0125917", "", "NT17", "L")
# 90   fn_showArticle("AR0125884", "", "NT17", "L")
# 91   fn_showArticle("AR0125701", "", "NT17", "L")
# 92   fn_showArticle("AR0125557", "", "NT17", "L")
# 93   fn_showArticle("AR0125350", "", "NT17", "L")
# 94   fn_showArticle("AR0124795", "", "NT17", "L")
# 95   fn_showArticle("AR0126490", "", "NT16", "L")
# 96   fn_showArticle("AR0126489", "", "NT16", "L")
# 97   fn_showArticle("AR0126436", "", "NT16", "L")
# 98   fn_showArticle("AR0126402", "", "NT16", "L")
# 99   fn_showArticle("AR0126363", "", "NT16", "L")
# 100  fn_showArticle("AR0126362", "", "NT16", "L")
# 101  fn_showArticle("AR0126361", "", "NT16", "L")
# 102  fn_showArticle("AR0126155", "", "NT02", "L")
# 103  fn_showArticle("AR0126025", "", "NT02", "L")
# 104  fn_showArticle("AR0125877", "", "NT02", "L")
# 105  fn_showArticle("AR0125732", "", "NT02", "L")
# 106  fn_showArticle("AR0125726", "", "NT02", "L")
# 107  fn_showArticle("AR0125725", "", "NT02", "L")
# 108  fn_showArticle("AR0125707", "", "NT02", "L")
#
# [109 rows x 2 columns]

# %%
df.to_csv("nk-news.csv", index=False)
